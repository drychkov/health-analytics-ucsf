# %% [markdown]
# # Data Analytics in Healthcare
#
# ## Week 1 - Data Aquisition
#
# Objectives:
#
# - Introduction to JSON
# - Learn to get data from an API
# - Use a scrapy spider to crawl a website
# - Use Pandas to format JSON

# %%
import scrapy
import requests
import pandas as pd
from pprint import pprint
import json

# %% [markdown]
# #### Intro to JSON (from [this link](https://www.digitalocean.com/community/tutorials/an-introduction-to-json))
#
# “JSON” stands for “JavaScript Object Notation”. It’s a lightweight, text-based format, and is frequently used in conjunction with REST APIs and web-based services. You can find more details on the specifics of the JSON format at the JSON web site.
#
# The basic structures of JSON are:
#
# * A set of name/value pairs
#
# * An ordered list of values
#
# A JSON object is a key-value data format that is typically rendered in curly braces. When you’re working with JSON, you’ll likely see JSON objects in a .json file, but they can also exist as a JSON object or string within the context of a program.
#
# A JSON object looks something like this
#
#
# ```
# {
#   "first_name" : "Sammy",
#   "last_name" : "Shark",
#   "location" : "Ocean",
#   "online" : true,
#   "followers" : 987
# }
# ```
# JSON can store nested objects in JSON format in addition to nested arrays. These objects and arrays will be passed as values assigned to keys, and typically will be comprised of key-value pairs as well.
#
# Nested Objects
#
# In the users.json file below, for each of the four users ("sammy", "jesse", "drew", "jamie") there is a nested JSON object passed as the value for each of the users, with its own nested keys of "username" and "location" that relate to each of the users. The first nested JSON object is highlighted below.
#
# ```
# {
#   "sammy" : {
#     "username"  : "SammyShark",
#     "location"  : "Indian Ocean",
#     "online"    : true,
#     "followers" : 987
#   },
#   "jesse" : {
#     "username"  : "JesseOctopus",
#     "location"  : "Pacific Ocean",
#     "online"    : false,
#     "followers" : 432
#   },
#   "drew" : {
#     "username"  : "DrewSquid",
#     "location"  : "Atlantic Ocean",
#     "online"    : false,
#     "followers" : 321
#   },
#   "jamie" : {
#     "username"  : "JamieMantisShrimp",
#     "location"  : "Pacific Ocean",
#     "online"    : true,
#     "followers" : 654
#   }
# }
# ```
#
# In the example above, curly braces are used throughout to form a nested JSON object with associated username and location data for each of four users. Just like any other value, when using objects, commas are used to separate elements.
#
# Nested Arrays
#
# Data can also be nested within the JSON format by using JavaScript arrays that are passed as a value. JavaScript uses square brackets [ ] on either end of its array type. Arrays are ordered collections and can contain values of differing data types.
#
# We may use an array when we are dealing with a lot of data that can be easily grouped together, like when there are various websites and social media profiles associated with a single user.
#
# With the first nested array highlighted, a user profile for Sammy may look like this:
#
# ```
# {
#   "first_name" : "Sammy",
#   "last_name" : "Shark",
#   "location" : "Ocean",
#   "websites" : [
#     {
#       "description" : "work",
#       "URL" : "https://www.digitalocean.com/"
#     },
#     {
#       "desciption" : "tutorials",
#       "URL" : "https://www.digitalocean.com/community/tutorials"
#     }
#   ],
#   "social_media" : [
#     {
#       "description" : "twitter",
#       "link" : "https://twitter.com/digitalocean"
#     },
#     {
#       "description" : "facebook",
#       "link" : "https://www.facebook.com/DigitalOceanCloudHosting"
#     },
#     {
#       "description" : "github",
#       "link" : "https://github.com/digitalocean"
#     }
#   ]
# }
# ```

# %% [markdown]
# ### 1. Get the the data from from the API
#
# Go the the website https://clinicaltrialsapi.cancer.gov/v1/ and explore the API. Download data from the trial given as an example (NCT02194738) and view the data. The function given to you used the GET function from the requests library in Python. pprint will allow you to view the JSON in a formatted manner. Be careful, these responses can be large!

# %%
def get_response_json(api_args, api_root="https://clinicaltrialsapi.cancer.gov/v1/"):
    """
    This function returns the json of a GET response
    
    arguments:
    api_root -- str, the root website of the API
    api_args -- str, the arguements to the API
    
    returns
    json response, str
    """
    return requests.get(api_root + api_args).json()

# %%
# Retrieve the data using the argument and store it in a variable
json_text = get_response_json(api_args="clinical-trial/NCT02194738")

# %%
# Use pprint to print the text
pprint(json_text)
# Out:
# {u'accepts_healthy_volunteers_indicator': u'NO',
#  u'acronym': None,
#  u'amendment_date': u'2016-03-23T00:00:00',
#  u'anatomic_sites': [u'Lung'],
#  u'arms': [{u'arm_description': u'Patients undergo collection of blood and tissue samples for EGFR and ALK testing via direct sequencing and FISH. Patients that have had surgery prior to pre-registration will submit samples from the previous surgery for testing.',
#             u'arm_name': u'Ancillary-Correlative (marker identification and sequencing)',
#             u'arm_type': None,
#             u'interventions': [{u'intervention_code': u'C38113',
#                                 u'intervention_description': None,
#                                 u'intervention_name': u'Cytology Specimen Collection Procedure',
#                                 u'intervention_type': u'Other',
#                                 u'synonyms': [u'Cytology Specimen Collection Procedure',
#                                               u'Cytologic Sampling']},
#                                {u'intervention_code': u'C64263',
#                                 u'intervention_description': None,
#                                 u'intervention_name': u'Laboratory Biomarker Analysis',
#                                 u'intervention_type': u'Other',
#                                 u'synonyms': [u'Laboratory Biomarker Analysis']}]}],
#  u'associated_studies': None,
#  u'bio_specimen': {u'f1': u'bio_specimen_description',
#                    u'f2': u'Tissue and blood',
#                    u'f3': u'bio_specimen_retention_code',
#                    u'f4': u'SAMPLES_WITH_DNA'},
#  u'biomarkers': None,
#  u'brief_summary': u'This research trial studies genetic testing in screening patients with stage IB-IIIA non-small cell lung cancer that has been or will be removed by surgery. Studying the genes in a patient\u2019s tumor cells may help doctors select the best treatment for patients that have certain genetic changes.',
#  u'brief_title': u'Genetic Testing in Screening Patients with Stage IB-IIIA Non-Small Cell Lung Cancer That Has Been or Will Be Removed by Surgery (The ALCHEMIST Screening Trial)',
#  u'ccr_id': None,
#  u'central_contact': {u'central_contact_email': None,
#                       u'central_contact_name': None,
#                       u'central_contact_phone': None,
#                       u'central_contact_type': None},
#  u'classification_code': None,
#  u'collaborators': [{u'functional_role': u'FUNDING_SOURCE',
#                      u'name': u'National Cancer Institute'}],
#  u'completion_date': None,
#  u'completion_date_type_code': None,
#  u'ctep_id': u'A151216',
#  u'current_trial_status': u'Active',
#  u'current_trial_status_date': u'2014-08-18',
#  u'dcp_id': None,
#  u'detail_description': u'PRIMARY OBJECTIVES:\r\nI. To centrally test resected non-small cell lung cancer (NSCLC) for genetic mutations to facilitate accrual to randomized adjuvant studies.\r\nII. To obtain clinically annotated tumor tissue and patient-matched non-malignant deoxyribonucleic acid (DNA) from peripheral blood, as well as detailed epidemiologic and clinical follow-up data, to allow clinically annotated advanced genomic analyses in concert with the National Cancer Institute (NCI) Center for Cancer Genomics (CCG).\r\n\r\nSECONDARY OBJECTIVES:\r\nI. To characterize the natural history of molecularly characterized NSCLC to allow subsequent development of targeted therapies against genotype-defined subpopulations in the adjuvant and recurrent settings.\r\nII. To cross-validate local genotyping assays for epidermal growth factor receptor (EGFR) and anaplastic lymphoma receptor tyrosine kinase (ALK) with a central reference standard.\r\n\r\nTERTIARY OBJECTIVES:\r\nI. To study the genomic evolution of lung cancers by comparing genomic characteristics at resection and at recurrence.\r\nII. To understand reasons behind lack of enrollment to adjuvant targeted therapy studies for potentially eligible patients.\r\n\r\nOUTLINE: \r\nPatients undergo collection of blood and tissue samples for EGFR, ALK, and programmed cell death protein 1 (PD-1)/programmed cell death ligand 1 (PD-L1)/cytotoxic t-lymphocyte-associated protein 4 (CTLA-4) testing via direct sequencing, fluorescence in situ hybridization (FISH) and immunohistochemistry (IHC). Patients that have had surgery prior to pre-registration will submit samples from the previous surgery for testing. \r\n\r\nAfter completion of study, patients that are not enrolled on either A081105, E4512, or EA5142 are followed up every 6 months for 5 years.',
#  u'diseases': [{u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C6689',
#                 u'parents': [u'C8766', u'C5646'],
#                 u'preferred_name': u'Stage IIIA Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IIIA Squamous Cell Lung Carcinoma',
#                               u'Stage IIIA Squamous Cell Carcinoma of Lung',
#                               u'Stage IIIA Squamous Cell Carcinoma of the Lung',
#                               u'Stage IIIA Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C6691',
#                 u'parents': [u'C8765', u'C5645'],
#                 u'preferred_name': u'Stage IIB Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IIB Squamous Cell Lung Carcinoma',
#                               u'Stage IIB Squamous Cell Carcinoma of Lung',
#                               u'Stage IIB Squamous Cell Carcinoma of the Lung',
#                               u'Stage IIB Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C6688',
#                 u'parents': [u'C8765', u'C5644'],
#                 u'preferred_name': u'Stage IIA Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IIA Squamous Cell Lung Carcinoma',
#                               u'Stage IIA Squamous Cell Carcinoma of Lung',
#                               u'Stage IIA Squamous Cell Carcinoma of the Lung',
#                               u'Stage IIA Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C6692',
#                 u'parents': [u'C8764', u'C5643'],
#                 u'preferred_name': u'Stage IB Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IB Squamous Cell Lung Carcinoma',
#                               u'Stage IB Squamous Cell Carcinoma of Lung',
#                               u'Stage IB Squamous Cell Carcinoma of the Lung',
#                               u'Stage IB Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': u'CDR0000682740',
#                 u'display_name': u'Stage IB Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5653',
#                 u'parents': [u'C6671', u'C5643'],
#                 u'preferred_name': u'Stage IB Non-Small Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IB Non-Small Cell Lung Carcinoma',
#                               u'Stage IB Non-Oat Cell Carcinoma of Lung',
#                               u'Stage IB Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage IB Non-Oat Cell Lung Carcinoma',
#                               u'Stage IB Non-Small Cell Carcinoma of Lung',
#                               u'Stage IB Non-Small Cell Carcinoma of the Lung',
#                               u'Stage IB Non-Small Cell Lung Carcinoma AJCC v7',
#                               u'stage IB non-small cell lung cancer']},
#                {u'disease_code': u'CDR0000682741',
#                 u'display_name': u'Stage IIA Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5655',
#                 u'parents': [u'C7777', u'C5644'],
#                 u'preferred_name': u'Stage IIA Non-Small Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IIA Non-Small Cell Lung Carcinoma',
#                               u'Stage IIA Non-Oat Cell Carcinoma of Lung',
#                               u'Stage IIA Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage IIA Non-Oat Cell Lung Carcinoma',
#                               u'Stage IIA Non-Small Cell Carcinoma of Lung',
#                               u'Stage IIA Non-Small Cell Carcinoma of the Lung',
#                               u'Stage IIA Non-Small Cell Lung Carcinoma AJCC v7',
#                               u'stage IIA non-small cell lung cancer']},
#                {u'disease_code': u'CDR0000682742',
#                 u'display_name': u'Stage IIB Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5654',
#                 u'parents': [u'C7777', u'C5645'],
#                 u'preferred_name': u'Stage IIB Non-Small Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage IIB Non-Small Cell Lung Carcinoma',
#                               u'Stage IIB Non-Oat Cell Carcinoma of Lung',
#                               u'Stage IIB Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage IIB Non-Oat Cell Lung Carcinoma',
#                               u'Stage IIB Non-Small Cell Carcinoma of Lung',
#                               u'Stage IIB Non-Small Cell Carcinoma of the Lung',
#                               u'Stage IIB Non-Small Cell Lung Carcinoma AJCC v7',
#                               u'stage IIB non-small cell lung cancer']},
#                {u'disease_code': u'CDR0000038938',
#                 u'display_name': u'Stage IIIA Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C9102',
#                 u'parents': [u'C7778', u'C5646'],
#                 u'preferred_name': u'Stage IIIA Non-Small Cell Lung Cancer',
#                 u'synonyms': [u'Stage IIIA Non-Small Cell Lung Cancer',
#                               u'Non Small Cell Lung Cancer Stage IIIA',
#                               u'Non Small Cell Lung Cancer, Stage IIIA',
#                               u'Stage IIIA NSCLC',
#                               u'Stage IIIA Non-Oat Cell Carcinoma of Lung',
#                               u'Stage IIIA Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage IIIA Non-Oat Cell Lung Carcinoma',
#                               u'Stage IIIA Non-Small Cell Carcinoma of Lung',
#                               u'Stage IIIA Non-Small Cell Carcinoma of the Lung',
#                               u'Stage IIIA Non-Small Cell Lung Cancer AJCC v7',
#                               u'Stage IIIA Non-Small Cell Lung Carcinoma',
#                               u'stage IIIA non-small cell lung cancer']},
#                {u'disease_code': u'CDR0000041109',
#                 u'display_name': u'Large Cell Lung Cancer',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C4450',
#                 u'parents': [u'C3780', u'C2926'],
#                 u'preferred_name': u'Large Cell Lung Carcinoma',
#                 u'synonyms': [u'Large Cell Lung Carcinoma',
#                               u'Anaplastic Lung Carcinoma',
#                               u'Large Cell Carcinoma of Lung',
#                               u'Large Cell Carcinoma of the Lung',
#                               u'Large Cell Undifferentiated Lung Carcinoma']},
#                {u'disease_code': u'CDR0000039837',
#                 u'display_name': u'Lung Adenocarcinoma',
#                 u'inclusion_indicator': u'TRIAL',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3512',
#                 u'parents': [u'C2926', u'C27745'],
#                 u'preferred_name': u'Lung Adenocarcinoma',
#                 u'synonyms': [u'Lung Adenocarcinoma',
#                               u'Adenocarcinoma of Lung',
#                               u'Adenocarcinoma of the Lung',
#                               u'Lung adenocarcinoma']},
#                {u'disease_code': u'CDR0000040862',
#                 u'display_name': u'Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C2926',
#                 u'parents': [u'C7629', u'C65151', u'C4878'],
#                 u'preferred_name': u'Non-Small Cell Lung Carcinoma',
#                 u'synonyms': [u'Non-Small Cell Lung Carcinoma',
#                               u'NSCLC',
#                               u'NSCLC - Non-Small Cell Lung Cancer',
#                               u'Non Small Cell Lung Cancer NOS',
#                               u'Non-Small Cell Cancer of Lung',
#                               u'Non-Small Cell Cancer of the Lung',
#                               u'Non-Small Cell Carcinoma of Lung',
#                               u'Non-Small Cell Carcinoma of the Lung',
#                               u'Non-Small Cell Lung Cancer',
#                               u'Non-small cell lung cancer, NOS',
#                               u'non-small cell lung cancer']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3200',
#                 u'parents': [u'C3406', u'C3355', u'C3198'],
#                 u'preferred_name': u'Lung Neoplasm',
#                 u'synonyms': [u'Lung Neoplasm',
#                               u'Lung Neoplasms',
#                               u'Lung Tumor',
#                               u'Neoplasm of Lung',
#                               u'Neoplasm of the Lung',
#                               u'Tumor of Lung',
#                               u'Tumor of the Lung']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3406',
#                 u'parents': [u'C35742', u'C3263'],
#                 u'preferred_name': u'Thoracic Neoplasm',
#                 u'synonyms': [u'Thoracic Neoplasm',
#                               u'Neoplasm of Thorax',
#                               u'Neoplasm of the Thorax',
#                               u'Thoracic Tumor',
#                               u'Tumor of Thorax',
#                               u'Tumor of the Thorax']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5644',
#                 u'parents': [u'C88889'],
#                 u'preferred_name': u'Stage IIA Lung Carcinoma',
#                 u'synonyms': [u'Stage IIA Lung Carcinoma',
#                               u'Stage IIA Carcinoma of Lung',
#                               u'Stage IIA Carcinoma of the Lung',
#                               u'Stage IIA Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5645',
#                 u'parents': [u'C88889'],
#                 u'preferred_name': u'Stage IIB Lung Carcinoma',
#                 u'synonyms': [u'Stage IIB Lung Carcinoma',
#                               u'Stage IIB Carcinoma of Lung',
#                               u'Stage IIB Carcinoma of the Lung',
#                               u'Stage IIB Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C2852',
#                 u'parents': [u'C7132', u'C2916'],
#                 u'preferred_name': u'Adenocarcinoma',
#                 u'synonyms': [u'Adenocarcinoma',
#                               u'ADENOCARCINOMA, MALIGNANT',
#                               u'Adenocarcinoma, NOS',
#                               u'adenocarcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C8764',
#                 u'parents': [u'C88888', u'C3493'],
#                 u'preferred_name': u'Stage I Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage I Squamous Cell Lung Carcinoma',
#                               u'Stage I Epidermoid Cell Carcinoma of Lung',
#                               u'Stage I Epidermoid Cell Carcinoma of the Lung',
#                               u'Stage I Epidermoid Cell Lung Carcinoma',
#                               u'Stage I Squamous Cell Carcinoma of Lung',
#                               u'Stage I Squamous Cell Carcinoma of the Lung',
#                               u'Stage I Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': u'CDR0000039286',
#                 u'display_name': u'Malignant Thoracic Neoplasm',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3576',
#                 u'parents': [u'C3406'],
#                 u'preferred_name': u'Malignant Thoracic Neoplasm',
#                 u'synonyms': [u'Malignant Thoracic Neoplasm',
#                               u'Malignant Neoplasm of Thorax',
#                               u'Malignant Neoplasm of the Thorax',
#                               u'Malignant Thoracic Tumor',
#                               u'Malignant Tumor of Thorax',
#                               u'Malignant Tumor of the Thorax']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C4571',
#                 u'parents': [u'C3355'],
#                 u'preferred_name': u'Malignant Respiratory Tract Neoplasm',
#                 u'synonyms': [u'Malignant Respiratory Tract Neoplasm',
#                               u'Malignant Neoplasm of Respiratory Tract',
#                               u'Malignant Neoplasm of the Respiratory Tract',
#                               u'Malignant Respiratory Tract Tumor',
#                               u'Malignant Tumor of Respiratory Tract',
#                               u'Malignant Tumor of the Respiratory Tract']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C7132',
#                 u'parents': [u'C3709'],
#                 u'preferred_name': u'Glandular Cell Neoplasm',
#                 u'synonyms': [u'Glandular Cell Neoplasm',
#                               u'Glandular Cell Epithelial Neoplasm',
#                               u'Glandular Cell Epithelium Neoplasm']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3262',
#                 u'parents': [u'C2991'],
#                 u'preferred_name': u'Neoplasm',
#                 u'synonyms': [u'Neoplasm',
#                               u'Neoplasia',
#                               u'Neoplastic Disease',
#                               u'Neoplastic Growth',
#                               u'neoplasia',
#                               u'neoplasm',
#                               u'tumor']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5643',
#                 u'parents': [u'C88888'],
#                 u'preferred_name': u'Stage IB Lung Carcinoma',
#                 u'synonyms': [u'Stage IB Lung Carcinoma',
#                               u'Stage IB Carcinoma of Lung',
#                               u'Stage IB Carcinoma of the Lung',
#                               u'Stage IB Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3792',
#                 u'parents': [u'C3709'],
#                 u'preferred_name': u'Squamous Cell Neoplasm',
#                 u'synonyms': [u'Squamous Cell Neoplasm',
#                               u'Epidermoid Cell Neoplasm',
#                               u'Epidermoid Cell Tumor',
#                               u'Squamous Cell Tumor']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3198',
#                 u'parents': [u'C35742', u'C26871'],
#                 u'preferred_name': u'Lung Disorder',
#                 u'synonyms': [u'Lung Disorder',
#                               u'Disorder of Lung',
#                               u'Lung Disorders',
#                               u'Pulmonary Disease',
#                               u'Pulmonary Diseases',
#                               u'Pulmonary Disorder',
#                               u'Pulmonary Disorders']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C26871',
#                 u'parents': [u'C27669'],
#                 u'preferred_name': u'Respiratory System Disorder',
#                 u'synonyms': [u'Respiratory System Disorder',
#                               u'Disorder of Respiratory System',
#                               u'Respiratory Disorder']},
#                {u'disease_code': u'CDR0000040108',
#                 u'display_name': u'Squamous Cell Lung Cancer',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3493',
#                 u'parents': [u'C4878', u'C2929'],
#                 u'preferred_name': u'Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Squamous Cell Lung Carcinoma',
#                               u'Epidermoid Cell Carcinoma of Lung',
#                               u'Epidermoid Cell Carcinoma of the Lung',
#                               u'Epidermoid Cell Lung Carcinoma',
#                               u'Squamous Cell Carcinoma of Lung',
#                               u'Squamous Cell Carcinoma of the Lung',
#                               u'Squamous cell lung carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C65151',
#                 u'parents': [u'C2916'],
#                 u'preferred_name': u'Non-Small Cell Carcinoma',
#                 u'synonyms': [u'Non-Small Cell Carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'Squamous Cell Carcinoma',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C2929',
#                 u'parents': [u'C3792', u'C2916'],
#                 u'preferred_name': u'Squamous Cell Carcinoma',
#                 u'synonyms': [u'Squamous Cell Carcinoma',
#                               u'CARCINOMA, SQUAMOUS CELL, MALIGNANT',
#                               u'Epidermoid Carcinoma',
#                               u'Epidermoid Cell Cancer',
#                               u'Malignant Epidermoid Cell Neoplasm',
#                               u'Malignant Epidermoid Cell Tumor',
#                               u'Malignant Squamous Cell Neoplasm',
#                               u'Malignant Squamous Cell Tumor',
#                               u'Squamous Carcinoma',
#                               u'Squamous Cell Cancer',
#                               u'Squamous Cell Epithelioma',
#                               u'epidermoid carcinoma',
#                               u'squamous cell carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C8765',
#                 u'parents': [u'C88889', u'C3493'],
#                 u'preferred_name': u'Stage II Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage II Squamous Cell Lung Carcinoma',
#                               u'Lung Squamous Cell Carcinoma Stage II',
#                               u'Stage II Epidermoid Cell Carcinoma of Lung',
#                               u'Stage II Epidermoid Cell Carcinoma of the Lung',
#                               u'Stage II Epidermoid Cell Lung Carcinoma',
#                               u'Stage II Squamous Cell Carcinoma of Lung',
#                               u'Stage II Squamous Cell Carcinoma of the Lung',
#                               u'Stage II Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': u'CDR0000041226',
#                 u'display_name': u'Stage I Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C6671',
#                 u'parents': [u'C88888', u'C2926'],
#                 u'preferred_name': u'Stage I Non-Small Cell Lung Cancer',
#                 u'synonyms': [u'Stage I Non-Small Cell Lung Cancer',
#                               u'Stage I NSCLC',
#                               u'Stage I Non-Oat Cell Carcinoma of Lung',
#                               u'Stage I Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage I Non-Oat Cell Lung Carcinoma',
#                               u'Stage I Non-Small Cell Carcinoma of Lung',
#                               u'Stage I Non-Small Cell Carcinoma of the Lung',
#                               u'Stage I Non-Small Cell Lung Cancer AJCC v7',
#                               u'Stage I Non-Small Cell Lung Carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C2991',
#                 u'parents': [u'C7057'],
#                 u'preferred_name': u'Disease or Disorder',
#                 u'synonyms': [u'Disease or Disorder',
#                               u'Disease',
#                               u'Diseases',
#                               u'Diseases and Disorders',
#                               u'Disorder',
#                               u'Disorders',
#                               u'condition',
#                               u'disorder']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C27551',
#                 u'parents': [u'C2991'],
#                 u'preferred_name': u'Disorder by Site',
#                 u'synonyms': [u'Disorder by Site', u'Disease by Site']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C91232',
#                 u'parents': [u'C4878'],
#                 u'preferred_name': u'Lung Carcinoma by AJCC v7 Stage',
#                 u'synonyms': [u'Lung Carcinoma by AJCC v7 Stage']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3355',
#                 u'parents': [u'C3263', u'C26871'],
#                 u'preferred_name': u'Respiratory Tract Neoplasm',
#                 u'synonyms': [u'Respiratory Tract Neoplasm',
#                               u'Neoplasm of Respiratory Tract',
#                               u'Neoplasm of the Respiratory Tract',
#                               u'Respiratory Tract Tumor',
#                               u'Tumor of Respiratory Tract',
#                               u'Tumor of the Respiratory Tract']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C88890',
#                 u'parents': [u'C91232'],
#                 u'preferred_name': u'Stage III Lung Cancer',
#                 u'synonyms': [u'Stage III Lung Cancer',
#                               u'Stage III Lung Cancer AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C7057',
#                 u'parents': [u'root_node'],
#                 u'preferred_name': u'Disease, Disorder or Finding',
#                 u'synonyms': [u'Disease, Disorder or Finding']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C7377',
#                 u'parents': [u'C4571', u'C3576', u'C3200'],
#                 u'preferred_name': u'Malignant Lung Neoplasm',
#                 u'synonyms': [u'Malignant Lung Neoplasm',
#                               u'Malignant Lung Tumor',
#                               u'Malignant Neoplasm of Lung',
#                               u'Malignant Neoplasm of the Lung',
#                               u'Malignant Tumor of Lung',
#                               u'Malignant Tumor of the Lung']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C4741',
#                 u'parents': [u'C3262'],
#                 u'preferred_name': u'Neoplasm by Morphology',
#                 u'synonyms': [u'Neoplasm by Morphology']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C27669',
#                 u'parents': [u'C27551'],
#                 u'preferred_name': u'Respiratory and Thoracic Disorder',
#                 u'synonyms': [u'Respiratory and Thoracic Disorder',
#                               u'Respiratory and Thoracic Disease',
#                               u'Respiratory, Thoracic, and Mediastinal Disease',
#                               u'Respiratory, Thoracic, and Mediastinal Disorder']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C88889',
#                 u'parents': [u'C91232'],
#                 u'preferred_name': u'Stage II Lung Cancer',
#                 u'synonyms': [u'Stage II Lung Cancer',
#                               u'Stage II Lung Cancer AJCC v7']},
#                {u'disease_code': u'CDR0000041428',
#                 u'display_name': u'Stage III Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C7778',
#                 u'parents': [u'C88890', u'C2926'],
#                 u'preferred_name': u'Stage III Non-Small Cell Lung Cancer',
#                 u'synonyms': [u'Stage III Non-Small Cell Lung Cancer',
#                               u'Stage III NSCLC',
#                               u'Stage III Non-Oat Cell Carcinoma of Lung',
#                               u'Stage III Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage III Non-Oat Cell Lung Carcinoma',
#                               u'Stage III Non-Small Cell Carcinoma of Lung',
#                               u'Stage III Non-Small Cell Carcinoma of the Lung',
#                               u'Stage III Non-Small Cell Lung Cancer AJCC v7',
#                               u'Stage III Non-Small Cell Lung Carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C5646',
#                 u'parents': [u'C88890'],
#                 u'preferred_name': u'Stage IIIA Lung Carcinoma',
#                 u'synonyms': [u'Stage IIIA Lung Carcinoma',
#                               u'Stage IIIA Carcinoma of Lung',
#                               u'Stage IIIA Carcinoma of the Lung',
#                               u'Stage IIIA Lung Carcinoma AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C27745',
#                 u'parents': [u'C65151', u'C2852'],
#                 u'preferred_name': u'Non-Small Cell Adenocarcinoma',
#                 u'synonyms': [u'Non-Small Cell Adenocarcinoma',
#                               u'Nonsmall Cell Adenocarcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C8766',
#                 u'parents': [u'C88890', u'C3493'],
#                 u'preferred_name': u'Stage III Squamous Cell Lung Carcinoma',
#                 u'synonyms': [u'Stage III Squamous Cell Lung Carcinoma',
#                               u'Lung Squamous Cell Carcinoma Stage III',
#                               u'Stage III Epidermoid Cell Carcinoma of Lung',
#                               u'Stage III Epidermoid Cell Carcinoma of the Lung',
#                               u'Stage III Epidermoid Cell Lung Carcinoma',
#                               u'Stage III Squamous Cell Carcinoma of Lung',
#                               u'Stage III Squamous Cell Carcinoma of the Lung',
#                               u'Stage III Squamous Cell Lung Carcinoma AJCC v7']},
#                {u'disease_code': u'CDR0000040209',
#                 u'display_name': u'Lung Cancer',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C4878',
#                 u'parents': [u'C7377', u'C2916'],
#                 u'preferred_name': u'Lung Carcinoma',
#                 u'synonyms': [u'Lung Carcinoma',
#                               u'Cancer of Lung',
#                               u'Cancer of the Lung',
#                               u'Carcinoma of Lung',
#                               u'Carcinoma of the Lung',
#                               u'Lung Cancer',
#                               u'Lung cancer, NOS',
#                               u'lung cancer']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C2916',
#                 u'parents': [u'C3709'],
#                 u'preferred_name': u'Carcinoma',
#                 u'synonyms': [u'Carcinoma',
#                               u'CARCINOMA, MALIGNANT',
#                               u'Carcinoma, NOS',
#                               u'Epithelial Carcinoma',
#                               u'Epithelioma Malignant',
#                               u'Malignant Epithelial Neoplasm',
#                               u'Malignant Epithelial Tumor',
#                               u'Malignant Epithelioma',
#                               u'carcinoma',
#                               u'epithelial carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3709',
#                 u'parents': [u'C4741'],
#                 u'preferred_name': u'Epithelial Neoplasm',
#                 u'synonyms': [u'Epithelial Neoplasm',
#                               u'Epithelial Neoplasms, NOS',
#                               u'Epithelioma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3263',
#                 u'parents': [u'C3262'],
#                 u'preferred_name': u'Neoplasm by Site',
#                 u'synonyms': [u'Neoplasm by Site']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C88888',
#                 u'parents': [u'C91232'],
#                 u'preferred_name': u'Stage I Lung Cancer',
#                 u'synonyms': [u'Stage I Lung Cancer',
#                               u'Stage I Lung Cancer AJCC v7']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C35742',
#                 u'parents': [u'C27669'],
#                 u'preferred_name': u'Thoracic Disorder',
#                 u'synonyms': [u'Thoracic Disorder', u'Thoracic Disease']},
#                {u'disease_code': u'CDR0000041327',
#                 u'display_name': u'Stage II Non-Small Cell Lung Cancer',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C7777',
#                 u'parents': [u'C88889', u'C2926'],
#                 u'preferred_name': u'Stage II Non-Small Cell Lung Cancer',
#                 u'synonyms': [u'Stage II Non-Small Cell Lung Cancer',
#                               u'Non -Small Cell Lung Cancer Stage II',
#                               u'Non Small Cell Lung Cancer Stage II',
#                               u'Stage II Non-Oat Cell Carcinoma of Lung',
#                               u'Stage II Non-Oat Cell Carcinoma of the Lung',
#                               u'Stage II Non-Oat Cell Lung Carcinoma',
#                               u'Stage II Non-Small Cell Carcinoma of Lung',
#                               u'Stage II Non-Small Cell Carcinoma of the Lung',
#                               u'Stage II Non-Small Cell Lung Cancer AJCC v7',
#                               u'Stage II Non-Small Cell Lung Carcinoma']},
#                {u'disease_code': None,
#                 u'display_name': u'',
#                 u'inclusion_indicator': u'TREE',
#                 u'lead_disease_indicator': None,
#                 u'nci_thesaurus_concept_id': u'C3780',
#                 u'parents': [u'C2916'],
#                 u'preferred_name': u'Large Cell Carcinoma',
#                 u'synonyms': [u'Large Cell Carcinoma',
#                               u'Carcinoma, Large Cell',
#                               u'large cell carcinoma']}],
#  u'eligibility': {u'structured': {u'gender': u'BOTH',
#                                   u'max_age': u'999 Years',
#                                   u'max_age_in_years': 999,
#                                   u'max_age_number': 999,
#                                   u'max_age_unit': u'Years',
#                                   u'min_age': u'18 Years',
#                                   u'min_age_in_years': 18,
#                                   u'min_age_number': 18,
#                                   u'min_age_unit': u'Years'},
#                   u'unstructured': [{u'description': u'PATIENT PRE-REGISTRATION ELIGIBILITY CRITERIA:',
#                                      u'display_order': 1,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'For pre-surgical patients\r\n* Suspected diagnosis of resectable non-small cell lung cancer; patients with squamous cell carcinoma are eligible only if the registering site has EA5142 institutional review board (IRB) approved\r\n* Suspected clinical stage of IIIA, II or large IB (defined as size >= 4cm)',
#                                      u'display_order': 2,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'For post-surgical patients\r\n* Completely resected non-small cell lung cancer; patients with squamous cell carcinoma are eligible only if the registering site has EA5142 IRB approved\r\n* Pathologic stage IIIA, II or IB (defined as size >= 4 cm)',
#                                      u'display_order': 3,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'Eastern Cooperative Oncology Group (ECOG) performance status 0-1',
#                                      u'display_order': 4,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'No patients who have received neoadjuvant therapy (chemo- or radio-therapy) for this lung cancer',
#                                      u'display_order': 5,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'No prior or concurrent malignancies within 5 years, except non-melanoma skin carcinoma or in situ carcinomas; a secondary primary lung cancer is considered a concurrent malignancy and would make a patient ineligible for A151216',
#                                      u'display_order': 6,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'No prior treatment with agents targeting EGFR mutation, ALK rearrangement, and PD-1/PD-L1/CTLA-4',
#                                      u'display_order': 7,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'No patients known to be pregnant or lactating',
#                                      u'display_order': 8,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'Patients who have had local genotyping are eligible, regardless of the local result',
#                                      u'display_order': 9,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'No patients with recurrence of lung cancer after prior resection',
#                                      u'display_order': 10,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'Note: Post-surgical patients should proceed to registration immediately following preregistration',
#                                      u'display_order': 11,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'PATIENT REGISTRATION ELIGIBILITY CRITERIA:',
#                                      u'display_order': 12,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'Completely resected NSCLC; patients with squamous cell carcinoma are eligible only if the registering site has EA5142 IRB approved',
#                                      u'display_order': 13,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'Pathologic stage IIIA, II, or large IB (defined as size >= 4 cm)',
#                                      u'display_order': 14,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'Tissue available for the required analyses',
#                                      u'display_order': 15,
#                                      u'inclusion_indicator': True},
#                                     {u'description': u'In order to allow for time for central genotyping and eligibility for the ALCHEMIST treatment trial, patients must register within the following eligibility windows, depending on the adjuvant treatment approach:\r\n* If no adjuvant therapy, register patient within 75 days following surgery\r\n* If adjuvant chemotherapy only, register patient within 225 days following surgery\r\n* If adjuvant chemotherapy and radiation, register patient within 285 days following surgery',
#                                      u'display_order': 16,
#                                      u'inclusion_indicator': True}]},
#  u'interventional_model': None,
#  u'keywords': None,
#  u'lead_org': u'Alliance for Clinical Trials in Oncology',
#  u'masking': {u'masking': None,
#               u'masking_allocation_code': None,
#               u'masking_role_caregiver': None,
#               u'masking_role_investigator': None,
#               u'masking_role_outcome_assessor': None,
#               u'masking_role_subject': None},
#  u'minimum_target_accrual_number': 8300,
#  u'nci_id': u'NCI-2014-01509',
#  u'nct_id': u'NCT02194738',
#  u'number_of_arms': None,
#  u'official_title': u'Adjuvant Lung Cancer Enrichment Marker Identification and Sequencing Trial (ALCHEMIST)',
#  u'other_ids': [{u'name': u'Obsolete NCT study protocol identifier',
#                  u'value': u'NCT02200497'}],
#  u'phase': {u'phase': u'NA',
#             u'phase_additional_qualifier_code': None,
#             u'phase_other_text': None},
#  u'primary_purpose': {u'primary_purpose_additional_qualifier_code': None,
#                       u'primary_purpose_code': u'BASIC_SCIENCE',
#                       u'primary_purpose_other_text': None},
#  u'principal_investigator': u'Geoffrey Raymond Oxnard',
#  u'protocol_id': u'A151216',
#  u'record_verification_date': u'2016-11-21',
#  u'sampling_method_code': u'NON_PROBABILITY_SAMPLE',
#  u'sites': [{u'contact_email': u'kcheek@dmhhs.org',
#              u'contact_name': u'James Lloyd Wade',
#              u'contact_phone': u'217-876-4740',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'7245 Raider Road',
#              u'org_address_line_2': None,
# ...
#              u'contact_phone': u'505-925-0366',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'4901 Lang Northeast',
#              u'org_address_line_2': None,
#              u'org_city': u'Albuquerque',
#              u'org_coordinates': {u'lat': 35.1531, u'lon': -106.5756},
#              u'org_country': u'United States',
#              u'org_email': u'CLee@nmcca.org',
#              u'org_family': u'University of New Mexico Cancer Research & Treatment Center',
#              u'org_fax': None,
#              u'org_name': u'New Mexico Oncology Hematology Consultants',
#              u'org_phone': u'505-272-0530',
#              u'org_postal_code': u'87109',
#              u'org_state_or_province': u'NM',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2016-12-14',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2016-02-17'},
#             {u'contact_email': None,
#              u'contact_name': u'Jeffrey L. Berenberg',
#              u'contact_phone': u'808-524-6115',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'3420-B Kuhio Highway',
#              u'org_address_line_2': None,
#              u'org_city': u'Lihue',
#              u'org_coordinates': {u'lat': 21.9976, u'lon': -159.4158},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'University of Hawaii Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Wilcox Memorial Hospital and Kauai Medical Clinic',
#              u'org_phone': u'808-245-1100',
#              u'org_postal_code': u'96766',
#              u'org_state_or_province': u'HI',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2013-02-03',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2014-11-01'},
#             {u'contact_email': None,
#              u'contact_name': u'Jeffrey L. Berenberg',
#              u'contact_phone': u'808-524-6115',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'91-2135 Fort Weaver Road',
#              u'org_address_line_2': u'Suite B-120',
#              u'org_city': u'Ewa Beach',
#              u'org_coordinates': {u'lat': 21.3374, u'lon': -158.0179},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'University of Hawaii Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'The Cancer Center of Hawaii-Leeward',
#              u'org_phone': u'808-678-9000',
#              u'org_postal_code': u'96706',
#              u'org_state_or_province': u'HI',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2015-07-24',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2014-11-01'},
#             {u'contact_email': None,
#              u'contact_name': u'Christopher Gary Peterson',
#              u'contact_phone': u'877-405-6866',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'410 Dewey Street',
#              u'org_address_line_2': None,
#              u'org_city': u'Wisconsin Rapids',
#              u'org_coordinates': {u'lat': 44.3431, u'lon': -89.7334},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'University of Wisconsin Carbone Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Aspirus UW Cancer Center',
#              u'org_phone': u'608-262-5223',
#              u'org_postal_code': u'54494',
#              u'org_state_or_province': u'WI',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2015-10-15',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2016-02-05'},
#             {u'contact_email': u'unmcrsa@unmc.edu',
#              u'contact_name': u'Apar Kishor Ganti',
#              u'contact_phone': u'402-559-6941',
#              u'generic_contact': None,
#              u'local_site_identifier': u'A151216',
#              u'org_address_line_1': u'987680 Nebraska Medical Center',
#              u'org_address_line_2': None,
#              u'org_city': u'Omaha',
#              u'org_coordinates': {u'lat': 41.2551, u'lon': -95.9773},
#              u'org_country': u'United States',
#              u'org_email': u'unmcrsa@unmc.edu',
#              u'org_family': u'Fred & Pamela Buffett Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'University of Nebraska Medical Center',
#              u'org_phone': u'402-559-3853',
#              u'org_postal_code': u'68198',
#              u'org_state_or_province': u'NE',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2013-01-23',
#              u'org_to_family_relationship': u'ORGANIZATIONAL',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2016-01-22'},
#             {u'contact_email': u'ctnursenav@kumc.edu',
#              u'contact_name': u'Chao Hui Huang',
#              u'contact_phone': u'913-945-7552',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'3515 Broadway',
#              u'org_address_line_2': None,
#              u'org_city': u'Great Bend',
#              u'org_coordinates': {u'lat': 38.3903, u'lon': -98.8296},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'University of Kansas Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Saint Rose Ambulatory and Surgery Center',
#              u'org_phone': u'620-792-5511',
#              u'org_postal_code': u'67530',
#              u'org_state_or_province': u'KS',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2012-10-03',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'TEMPORARILY_CLOSED_TO_ACCRUAL',
#              u'recruitment_status_date': u'2017-04-07'},
#             {u'contact_email': None,
#              u'contact_name': u'Jeffrey Crawford',
#              u'contact_phone': u'888-275-3853',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'500 Launchwood Drive',
#              u'org_address_line_2': None,
#              u'org_city': u'Laurinburg',
#              u'org_coordinates': {u'lat': 34.7588, u'lon': -79.4468},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'Duke Cancer Institute',
#              u'org_fax': None,
#              u'org_name': u'Scotland Memorial Hospital-Laurinburg Cancer Center',
#              u'org_phone': u'877-762-2735',
#              u'org_postal_code': u'28352',
#              u'org_state_or_province': u'NC',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2015-07-27',
#              u'org_to_family_relationship': u'ORGANIZATIONAL',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2017-03-10'},
#             {u'contact_email': None,
#              u'contact_name': u'Gamini S. Soori',
#              u'contact_phone': u'402-393-3110',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'4021 Avenue B',
#              u'org_address_line_2': None,
#              u'org_city': u'Scottsbluff',
#              u'org_coordinates': {u'lat': 41.9186, u'lon': -103.6441},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'Fred & Pamela Buffett Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Regional West Medical Center',
#              u'org_phone': None,
#              u'org_postal_code': u'69361',
#              u'org_state_or_province': u'NE',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2008-12-31',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2014-12-02'},
#             {u'contact_email': u'cancer@northwestern.edu',
#              u'contact_name': u'Nisha A. Mohindra',
#              u'contact_phone': u'312-695-1301',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'303 East Chicago Avenue',
#              u'org_address_line_2': None,
#              u'org_city': u'Chicago',
#              u'org_coordinates': {u'lat': 41.8946, u'lon': -87.6187},
#              u'org_country': u'United States',
#              u'org_email': u'cancer@northwestern.edu',
#              u'org_family': u'Robert H. Lurie Comprehensive Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Northwestern University',
#              u'org_phone': u'312-695-1301',
#              u'org_postal_code': u'60611',
#              u'org_state_or_province': u'IL',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2015-08-18',
#              u'org_to_family_relationship': u'ORGANIZATIONAL',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2017-01-19'},
#             {u'contact_email': None,
#              u'contact_name': u'James Earl Radford',
#              u'contact_phone': u'828-696-4716',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'1824 Pisgah Drive',
#              u'org_address_line_2': None,
#              u'org_city': u'Hendersonville',
#              u'org_coordinates': {u'lat': 35.3558, u'lon': -82.5083},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'UNC Lineberger Comprehensive Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Hendersonville Hematology and Oncology at Pardee',
#              u'org_phone': u'828-696-4716',
#              u'org_postal_code': u'28791',
#              u'org_state_or_province': u'NC',
#              u'org_status': u'INACTIVE',
#              u'org_status_date': u'2017-03-16',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2014-10-08'},
#             {u'contact_email': u'cancer.research.nurse@dartmouth.edu',
#              u'contact_name': u'Konstantin Hristov Dragnev',
#              u'contact_phone': u'800-639-6918',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'One Medical Center Drive',
#              u'org_address_line_2': None,
#              u'org_city': u'Lebanon',
#              u'org_coordinates': {u'lat': 43.7029, u'lon': -72.2895},
#              u'org_country': u'United States',
#              u'org_email': u'cancer.research.nurse@dartmouth.edu',
#              u'org_family': u'Norris Cotton Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Dartmouth Hitchcock Medical Center',
#              u'org_phone': u'603-650-7609',
#              u'org_postal_code': u'03756',
#              u'org_state_or_province': u'NH',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2012-03-29',
#              u'org_to_family_relationship': u'ORGANIZATIONAL',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2015-01-06'},
#             {u'contact_email': None,
#              u'contact_name': u'Dhimant R. Patel',
#              u'contact_phone': u'800-252-2990',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'36500 Aurora Drive',
#              u'org_address_line_2': None,
#              u'org_city': u'Summit',
#              u'org_coordinates': {u'lat': 43.114, u'lon': -88.4931},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'University of Wisconsin Carbone Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Aurora Medical Center in Summit',
#              u'org_phone': u'800-252-2990',
#              u'org_postal_code': u'53066',
#              u'org_state_or_province': u'WI',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2015-07-30',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2015-01-27'},
#             {u'contact_email': None,
#              u'contact_name': u'Smitha Patiyil Menon',
#              u'contact_phone': u'414-805-4380',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'8701 Watertown Plank Road',
#              u'org_address_line_2': None,
#              u'org_city': u'Milwaukee',
#              u'org_coordinates': {u'lat': 43.0503, u'lon': -88.0423},
#              u'org_country': u'United States',
#              u'org_email': None,
#              u'org_family': u'University of Wisconsin Carbone Cancer Center',
#              u'org_fax': None,
#              u'org_name': u'Froedtert and the Medical College of Wisconsin',
#              u'org_phone': u'414-805-4380',
#              u'org_postal_code': u'53226',
#              u'org_state_or_province': u'WI',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2008-12-31',
#              u'org_to_family_relationship': u'AFFILIATION',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2015-04-17'},
#             {u'contact_email': u'Jamesline@osumc.edu',
#              u'contact_name': u'Gregory A. Otterson',
#              u'contact_phone': u'800-293-5066',
#              u'generic_contact': None,
#              u'local_site_identifier': u'',
#              u'org_address_line_1': u'410 West Tenth Avenue',
#              u'org_address_line_2': None,
#              u'org_city': u'Columbus',
#              u'org_coordinates': {u'lat': 40.0051, u'lon': -83.0218},
#              u'org_country': u'United States',
#              u'org_email': u'Jamesline@osumc.edu',
#              u'org_family': u'Comprehensive Cancer Center - James Cancer Hospital & Solove Research Institute',
#              u'org_fax': None,
#              u'org_name': u'Ohio State University Comprehensive Cancer Center',
#              u'org_phone': u'866-627-7616',
#              u'org_postal_code': u'43210',
#              u'org_state_or_province': u'OH',
#              u'org_status': u'ACTIVE',
#              u'org_status_date': u'2014-12-02',
#              u'org_to_family_relationship': u'ORGANIZATIONAL',
#              u'org_tty': None,
#              u'recruitment_status': u'ACTIVE',
#              u'recruitment_status_date': u'2015-05-12'}],
#  u'start_date': u'2014-08-18',
#  u'start_date_type_code': u'ACTUAL',
#  u'study_model_code': u'CASE_ONLY',
#  u'study_model_other_text': u'Need to be reviewed by scientific abstractor',
#  u'study_population_description': u'Patients with stage IB-IIIA non-small cell lung cancer',
#  u'study_protocol_type': u'Non-interventional',
#  u'study_subtype_code': u'OBSERVATIONAL'}

# %% [markdown]
# ### 2. Query the API using arguments
#
# Read the documentation for the API on the website, and retrieve the data to get all trial IDs for all trials in NY where the eligibility criteria was restricted to women and whose primary purpose was basic science.

# %%
# Use the API documentation to understand the nature of the arguements. Chain them together, and get the response
api_args = "clinical-trials?eligibility.structured.gender=female&include=nct_id&sites.org_state_or_province=NY"

# store response
json_text = get_response_json(api_args=api_args)

# eyeball the response
pprint(json_text)
# Out:
# {u'total': 212,
#  u'trials': [{u'nct_id': u'NCT01272037'},
#              {u'nct_id': u'NCT02750826'},
#              {u'nct_id': u'NCT01953588'},
#              {u'nct_id': u'NCT00565851'},
#              {u'nct_id': u'NCT02311933'},
#              {u'nct_id': u'NCT01872975'},
#              {u'nct_id': u'NCT01101451'},
#              {u'nct_id': u'NCT02101788'},
#              {u'nct_id': u'NCT02065687'},
#              {u'nct_id': u'NCT02446600'}]}

# %% [markdown]
# ### 3. Structure the JSON data
#
# Pandas is a very useful python library that allows you to view data in tabular form. It is very good (and fast!) for viewing CSV file and even connecting to databases. For this exercise, we shall use it to structure the JSON data in a more readable format.
#
# Hint: use the function:
#
# ```pd.io.json.json_normalize()```
#
# (This will help it to read data from nested JSON files i.e. where dictionaries and lists are embedded within others).

# %%
# From the json text, retrive the list of trials by using the key
trial_array = json_text['trials']

# Using pandas functions, convert the JSON into a Data Frame.
trial_df = pd.io.json.json_normalize(trial_array)

# Use the head function to view what is in the data fram. Note the header name "nct_id".
print(trial_df.head())

# Each column can be accessed using the name
trail_list = list(trial_df["nct_id"])
# Out:
#         nct_id
# 0  NCT01272037
# 1  NCT02750826
# 2  NCT01953588
# 3  NCT00565851
# 4  NCT02311933

# %% [markdown]
# ### 4. Scrape Data using a spider
#
# In this part, we shall use Scrapy (another python library) to create a "Spider" to crawl the websites to gather data.
# Scrapy documentation has a nice tutorial to get started at https://doc.scrapy.org/en/latest/intro/tutorial.html. We shall be modifying the code here for our purpose.
#
# To get started you can type "!scrapy startproject tutorial" in a new cell. This allows you to run command line arguements from within Jupyter, which can often be handy. The command will create a directory structure that can be used by your Scrapy commands.
#
# The code from the tutorial is below:
#
# Your objective are:
#
# 1. Create a meaningful query (use the query from Part 2, if nothing comes to mind) to get data from the API
# 2. Then get ALL the data from the trials retrieved by your query, and save them in individual files.
#
# Be sure to change the name of the variable as well the class to something meaninful, and use "scrapy _spiderName_" from the command line to run the spider.
#
# HINT: Replace the url list in the code snippet below, and construct that list within the start_requests function. Remember to save the code (including the imports) in a file appropriately named (for e.g.

# %%
# !scrapy startproject tutorial

# %%
class QuotesSpider(scrapy.Spider):
    name = "quotes"

    def start_requests(self):
        urls = [
            'http://quotes.toscrape.com/page/1/',
            'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        page = response.url.split("/")[-2]
        filename = 'quotes-%s.html' % page
        with open(filename, 'wb') as f:
            f.write(response.body)
        self.log('Saved file %s' % filename)

# %% [markdown]
#  - METAL https://github.com/Kitware/MetaIO
#  - DICOM – Waveform An extension of Dicom for storing waveform data
#  - European Data Format (.edf, .rec)
#  - CSV (.csv),XML,TXT
#  - ecgML – A markup language for electrocardiogram data acquisition and analysis.
#  - EDF/EDF+ – European Data Format.
#  - FEF – File Exchange Format for Vital signs, CEN TS 14271.
#  - GDF v1.x – The General Data Format for biomedical signals – Version 1.x.
#  - GDF v2.x – The General Data Format for biomedical signals – Version 2.x.
#  - HL7aECG – Health Level 7 v3 annotated ECG.
#  - MFER – Medical waveform Format Encoding Rules
#  - OpenXDF – Open Exchange Data Format
#  - TDMS (.tdms)
#  - LVM (.lvm)
#  - SCP-ECG – Standard Communication Protocol for Computer assisted electrocardiography EN1064:2007,
#  - SIGIF – A digital SIGnal Interchange Format with application in neurophysiology.
#  - WFDB – Format of Physiobank
