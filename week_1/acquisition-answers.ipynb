# %% [markdown]
# # Data Analytics in Healthcare
#
# ## Week 1 - Data Aquisition
#
# Objectives:
#
# - Introduction to JSON
# - Learn to get data from an API
# - Use a scrapy spider to crawl a website
# - Use Pandas to format JSON

# %%
import scrapy
import requests
import pandas as pd
from pprint import pprint
import json

# %% [markdown]
# #### Intro to JSON (from [this link](https://www.digitalocean.com/community/tutorials/an-introduction-to-json))
#
# “JSON” stands for “JavaScript Object Notation”. It’s a lightweight, text-based format, and is frequently used in conjunction with REST APIs and web-based services. You can find more details on the specifics of the JSON format at the JSON web site.
#
# The basic structures of JSON are:
#
# * A set of name/value pairs
#
# * An ordered list of values
#
# A JSON object is a key-value data format that is typically rendered in curly braces. When you’re working with JSON, you’ll likely see JSON objects in a .json file, but they can also exist as a JSON object or string within the context of a program.
#
# A JSON object looks something like this
#
#
# ```
# {
#   "first_name" : "Sammy",
#   "last_name" : "Shark",
#   "location" : "Ocean",
#   "online" : true,
#   "followers" : 987
# }
# ```
# JSON can store nested objects in JSON format in addition to nested arrays. These objects and arrays will be passed as values assigned to keys, and typically will be comprised of key-value pairs as well.
#
# Nested Objects
#
# In the users.json file below, for each of the four users ("sammy", "jesse", "drew", "jamie") there is a nested JSON object passed as the value for each of the users, with its own nested keys of "username" and "location" that relate to each of the users. The first nested JSON object is highlighted below.
#
# ```
# {
#   "sammy" : {
#     "username"  : "SammyShark",
#     "location"  : "Indian Ocean",
#     "online"    : true,
#     "followers" : 987
#   },
#   "jesse" : {
#     "username"  : "JesseOctopus",
#     "location"  : "Pacific Ocean",
#     "online"    : false,
#     "followers" : 432
#   },
#   "drew" : {
#     "username"  : "DrewSquid",
#     "location"  : "Atlantic Ocean",
#     "online"    : false,
#     "followers" : 321
#   },
#   "jamie" : {
#     "username"  : "JamieMantisShrimp",
#     "location"  : "Pacific Ocean",
#     "online"    : true,
#     "followers" : 654
#   }
# }
# ```
#
# In the example above, curly braces are used throughout to form a nested JSON object with associated username and location data for each of four users. Just like any other value, when using objects, commas are used to separate elements.
#
# Nested Arrays
#
# Data can also be nested within the JSON format by using JavaScript arrays that are passed as a value. JavaScript uses square brackets [ ] on either end of its array type. Arrays are ordered collections and can contain values of differing data types.
#
# We may use an array when we are dealing with a lot of data that can be easily grouped together, like when there are various websites and social media profiles associated with a single user.
#
# With the first nested array highlighted, a user profile for Sammy may look like this:
#
# ```
# {
#   "first_name" : "Sammy",
#   "last_name" : "Shark",
#   "location" : "Ocean",
#   "websites" : [
#     {
#       "description" : "work",
#       "URL" : "https://www.digitalocean.com/"
#     },
#     {
#       "desciption" : "tutorials",
#       "URL" : "https://www.digitalocean.com/community/tutorials"
#     }
#   ],
#   "social_media" : [
#     {
#       "description" : "twitter",
#       "link" : "https://twitter.com/digitalocean"
#     },
#     {
#       "description" : "facebook",
#       "link" : "https://www.facebook.com/DigitalOceanCloudHosting"
#     },
#     {
#       "description" : "github",
#       "link" : "https://github.com/digitalocean"
#     }
#   ]
# }
# ```

# %% [markdown]
# ### 1. Get the the data from from the API
#
# Go the the website https://clinicaltrialsapi.cancer.gov/v1/ and explore the API. Download data from the trial given as an example (NCT02194738) and view the data. The function given to you used the GET function from the requests library in Python. pprint will allow you to view the JSON in a formatted manner. Be careful, these responses can be large!

# %%
def get_response_json(api_args, api_root="https://clinicaltrialsapi.cancer.gov/v1/"):
    """
    This function returns the json of a GET response
    
    arguments:
    api_root -- str, the root website of the API
    api_args -- str, the arguements to the API
    
    returns
    json response, str
    """
    return requests.get(api_root + api_args).json()

# %%
# Retrieve the data using the argument and store it in a variable
json_text = get_response_json(api_args="clinical-trial/NCT02194738")

# %%
# Use pprint to print the text
pprint(json_text)
# Out:
# {'accepts_healthy_volunteers_indicator': 'NO',
#  'acronym': None,
#  'amendment_date': '2016-03-23T00:00:00',
#  'anatomic_sites': ['Lung'],
#  'arms': [{'arm_description': 'Patients undergo collection of blood and tissue '
#                               'samples for EGFR and ALK testing via direct '
#                               'sequencing and FISH. Patients that have had '
#                               'surgery prior to pre-registration will submit '
#                               'samples from the previous surgery for testing.',
#            'arm_name': 'Ancillary-Correlative (marker identification and '
#                        'sequencing)',
#            'arm_type': None,
#            'interventions': [{'intervention_code': 'C38113',
#                               'intervention_description': None,
#                               'intervention_name': 'Cytology Specimen '
#                                                    'Collection Procedure',
#                               'intervention_type': 'Other',
#                               'synonyms': ['Cytology Specimen Collection '
#                                            'Procedure',
#                                            'Cytologic Sampling']},
#                              {'intervention_code': 'C64263',
#                               'intervention_description': None,
#                               'intervention_name': 'Laboratory Biomarker '
#                                                    'Analysis',
#                               'intervention_type': 'Other',
#                               'synonyms': ['Laboratory Biomarker Analysis']}]}],
#  'associated_studies': None,
#  'bio_specimen': {'f1': 'bio_specimen_description',
#                   'f2': 'Tissue and blood',
#                   'f3': 'bio_specimen_retention_code',
#                   'f4': 'SAMPLES_WITH_DNA'},
#  'biomarkers': None,
#  'brief_summary': 'This research trial studies genetic testing in screening '
#                   'patients with stage IB-IIIA non-small cell lung cancer that '
#                   'has been or will be removed by surgery. Studying the genes '
#                   'in a patient’s tumor cells may help doctors select the best '
#                   'treatment for patients that have certain genetic changes.',
#  'brief_title': 'Genetic Testing in Screening Patients with Stage IB-IIIA '
#                 'Non-Small Cell Lung Cancer That Has Been or Will Be Removed '
#                 'by Surgery (The ALCHEMIST Screening Trial)',
#  'ccr_id': None,
#  'central_contact': {'central_contact_email': None,
#                      'central_contact_name': None,
#                      'central_contact_phone': None,
#                      'central_contact_type': None},
#  'classification_code': None,
#  'collaborators': [{'functional_role': 'FUNDING_SOURCE',
#                     'name': 'National Cancer Institute'}],
#  'completion_date': None,
#  'completion_date_type_code': None,
#  'ctep_id': 'A151216',
#  'current_trial_status': 'Active',
#  'current_trial_status_date': '2014-08-18',
#  'dcp_id': None,
#  'detail_description': 'PRIMARY OBJECTIVES:\r\n'
#                        'I. To centrally test resected non-small cell lung '
#                        'cancer (NSCLC) for genetic mutations to facilitate '
#                        'accrual to randomized adjuvant studies.\r\n'
#                        'II. To obtain clinically annotated tumor tissue and '
#                        'patient-matched non-malignant deoxyribonucleic acid '
#                        '(DNA) from peripheral blood, as well as detailed '
#                        'epidemiologic and clinical follow-up data, to allow '
#                        'clinically annotated advanced genomic analyses in '
#                        'concert with the National Cancer Institute (NCI) '
#                        'Center for Cancer Genomics (CCG).\r\n'
#                        '\r\n'
#                        'SECONDARY OBJECTIVES:\r\n'
#                        'I. To characterize the natural history of molecularly '
#                        'characterized NSCLC to allow subsequent development of '
#                        'targeted therapies against genotype-defined '
#                        'subpopulations in the adjuvant and recurrent '
#                        'settings.\r\n'
#                        'II. To cross-validate local genotyping assays for '
#                        'epidermal growth factor receptor (EGFR) and anaplastic '
#                        'lymphoma receptor tyrosine kinase (ALK) with a central '
#                        'reference standard.\r\n'
#                        '\r\n'
#                        'TERTIARY OBJECTIVES:\r\n'
#                        'I. To study the genomic evolution of lung cancers by '
#                        'comparing genomic characteristics at resection and at '
#                        'recurrence.\r\n'
#                        'II. To understand reasons behind lack of enrollment to '
#                        'adjuvant targeted therapy studies for potentially '
#                        'eligible patients.\r\n'
#                        '\r\n'
#                        'OUTLINE: \r\n'
#                        'Patients undergo collection of blood and tissue '
#                        'samples for EGFR, ALK, and programmed cell death '
#                        'protein 1 (PD-1)/programmed cell death ligand 1 '
#                        '(PD-L1)/cytotoxic t-lymphocyte-associated protein 4 '
#                        '(CTLA-4) testing via direct sequencing, fluorescence '
#                        'in situ hybridization (FISH) and immunohistochemistry '
#                        '(IHC). Patients that have had surgery prior to '
#                        'pre-registration will submit samples from the previous '
#                        'surgery for testing. \r\n'
#                        '\r\n'
#                        'After completion of study, patients that are not '
#                        'enrolled on either A081105, E4512, or EA5142 are '
#                        'followed up every 6 months for 5 years.',
#  'diseases': [{'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C6689',
#                'parents': ['C8766', 'C5646'],
#                'preferred_name': 'Stage IIIA Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage IIIA Squamous Cell Lung Carcinoma',
#                             'Stage IIIA Squamous Cell Carcinoma of Lung',
#                             'Stage IIIA Squamous Cell Carcinoma of the Lung',
#                             'Stage IIIA Squamous Cell Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C6691',
#                'parents': ['C8765', 'C5645'],
#                'preferred_name': 'Stage IIB Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage IIB Squamous Cell Lung Carcinoma',
#                             'Stage IIB Squamous Cell Carcinoma of Lung',
#                             'Stage IIB Squamous Cell Carcinoma of the Lung',
#                             'Stage IIB Squamous Cell Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C6688',
#                'parents': ['C8765', 'C5644'],
#                'preferred_name': 'Stage IIA Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage IIA Squamous Cell Lung Carcinoma',
#                             'Stage IIA Squamous Cell Carcinoma of Lung',
#                             'Stage IIA Squamous Cell Carcinoma of the Lung',
#                             'Stage IIA Squamous Cell Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C6692',
#                'parents': ['C8764', 'C5643'],
#                'preferred_name': 'Stage IB Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage IB Squamous Cell Lung Carcinoma',
#                             'Stage IB Squamous Cell Carcinoma of Lung',
#                             'Stage IB Squamous Cell Carcinoma of the Lung',
#                             'Stage IB Squamous Cell Lung Carcinoma AJCC v7']},
#               {'disease_code': 'CDR0000682740',
#                'display_name': 'Stage IB Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5653',
#                'parents': ['C6671', 'C5643'],
#                'preferred_name': 'Stage IB Non-Small Cell Lung Carcinoma',
#                'synonyms': ['Stage IB Non-Small Cell Lung Carcinoma',
#                             'Stage IB Non-Oat Cell Carcinoma of Lung',
#                             'Stage IB Non-Oat Cell Carcinoma of the Lung',
#                             'Stage IB Non-Oat Cell Lung Carcinoma',
#                             'Stage IB Non-Small Cell Carcinoma of Lung',
#                             'Stage IB Non-Small Cell Carcinoma of the Lung',
#                             'Stage IB Non-Small Cell Lung Carcinoma AJCC v7',
#                             'stage IB non-small cell lung cancer']},
#               {'disease_code': 'CDR0000682741',
#                'display_name': 'Stage IIA Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5655',
#                'parents': ['C7777', 'C5644'],
#                'preferred_name': 'Stage IIA Non-Small Cell Lung Carcinoma',
#                'synonyms': ['Stage IIA Non-Small Cell Lung Carcinoma',
#                             'Stage IIA Non-Oat Cell Carcinoma of Lung',
#                             'Stage IIA Non-Oat Cell Carcinoma of the Lung',
#                             'Stage IIA Non-Oat Cell Lung Carcinoma',
#                             'Stage IIA Non-Small Cell Carcinoma of Lung',
#                             'Stage IIA Non-Small Cell Carcinoma of the Lung',
#                             'Stage IIA Non-Small Cell Lung Carcinoma AJCC v7',
#                             'stage IIA non-small cell lung cancer']},
#               {'disease_code': 'CDR0000682742',
#                'display_name': 'Stage IIB Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5654',
#                'parents': ['C7777', 'C5645'],
#                'preferred_name': 'Stage IIB Non-Small Cell Lung Carcinoma',
#                'synonyms': ['Stage IIB Non-Small Cell Lung Carcinoma',
#                             'Stage IIB Non-Oat Cell Carcinoma of Lung',
#                             'Stage IIB Non-Oat Cell Carcinoma of the Lung',
#                             'Stage IIB Non-Oat Cell Lung Carcinoma',
#                             'Stage IIB Non-Small Cell Carcinoma of Lung',
#                             'Stage IIB Non-Small Cell Carcinoma of the Lung',
#                             'Stage IIB Non-Small Cell Lung Carcinoma AJCC v7',
#                             'stage IIB non-small cell lung cancer']},
#               {'disease_code': 'CDR0000038938',
#                'display_name': 'Stage IIIA Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C9102',
#                'parents': ['C7778', 'C5646'],
#                'preferred_name': 'Stage IIIA Non-Small Cell Lung Cancer',
#                'synonyms': ['Stage IIIA Non-Small Cell Lung Cancer',
#                             'Non Small Cell Lung Cancer Stage IIIA',
#                             'Non Small Cell Lung Cancer, Stage IIIA',
#                             'Stage IIIA NSCLC',
#                             'Stage IIIA Non-Oat Cell Carcinoma of Lung',
#                             'Stage IIIA Non-Oat Cell Carcinoma of the Lung',
#                             'Stage IIIA Non-Oat Cell Lung Carcinoma',
#                             'Stage IIIA Non-Small Cell Carcinoma of Lung',
#                             'Stage IIIA Non-Small Cell Carcinoma of the Lung',
#                             'Stage IIIA Non-Small Cell Lung Cancer AJCC v7',
#                             'Stage IIIA Non-Small Cell Lung Carcinoma',
#                             'stage IIIA non-small cell lung cancer']},
#               {'disease_code': 'CDR0000041109',
#                'display_name': 'Large Cell Lung Cancer',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C4450',
#                'parents': ['C3780', 'C2926'],
#                'preferred_name': 'Large Cell Lung Carcinoma',
#                'synonyms': ['Large Cell Lung Carcinoma',
#                             'Anaplastic Lung Carcinoma',
#                             'Large Cell Carcinoma of Lung',
#                             'Large Cell Carcinoma of the Lung',
#                             'Large Cell Undifferentiated Lung Carcinoma']},
#               {'disease_code': 'CDR0000039837',
#                'display_name': 'Lung Adenocarcinoma',
#                'inclusion_indicator': 'TRIAL',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3512',
#                'parents': ['C2926', 'C27745'],
#                'preferred_name': 'Lung Adenocarcinoma',
#                'synonyms': ['Lung Adenocarcinoma',
#                             'Adenocarcinoma of Lung',
#                             'Adenocarcinoma of the Lung',
#                             'Lung adenocarcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3198',
#                'parents': ['C35742', 'C26871'],
#                'preferred_name': 'Lung Disorder',
#                'synonyms': ['Lung Disorder',
#                             'Disorder of Lung',
#                             'Lung Disorders',
#                             'Pulmonary Disease',
#                             'Pulmonary Diseases',
#                             'Pulmonary Disorder',
#                             'Pulmonary Disorders']},
#               {'disease_code': 'CDR0000039286',
#                'display_name': 'Malignant Thoracic Neoplasm',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3576',
#                'parents': ['C3406'],
#                'preferred_name': 'Malignant Thoracic Neoplasm',
#                'synonyms': ['Malignant Thoracic Neoplasm',
#                             'Malignant Neoplasm of Thorax',
#                             'Malignant Neoplasm of the Thorax',
#                             'Malignant Thoracic Tumor',
#                             'Malignant Tumor of Thorax',
#                             'Malignant Tumor of the Thorax']},
#               {'disease_code': 'CDR0000040209',
#                'display_name': 'Lung Cancer',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C4878',
#                'parents': ['C7377', 'C2916'],
#                'preferred_name': 'Lung Carcinoma',
#                'synonyms': ['Lung Carcinoma',
#                             'Cancer of Lung',
#                             'Cancer of the Lung',
#                             'Carcinoma of Lung',
#                             'Carcinoma of the Lung',
#                             'Lung Cancer',
#                             'Lung cancer, NOS',
#                             'lung cancer']},
#               {'disease_code': 'CDR0000040862',
#                'display_name': 'Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C2926',
#                'parents': ['C7629', 'C65151', 'C4878'],
#                'preferred_name': 'Non-Small Cell Lung Carcinoma',
#                'synonyms': ['Non-Small Cell Lung Carcinoma',
#                             'NSCLC',
#                             'NSCLC - Non-Small Cell Lung Cancer',
#                             'Non Small Cell Lung Cancer NOS',
#                             'Non-Small Cell Cancer of Lung',
#                             'Non-Small Cell Cancer of the Lung',
#                             'Non-Small Cell Carcinoma of Lung',
#                             'Non-Small Cell Carcinoma of the Lung',
#                             'Non-Small Cell Lung Cancer',
#                             'Non-small cell lung cancer, NOS',
#                             'non-small cell lung cancer']},
#               {'disease_code': 'CDR0000041226',
#                'display_name': 'Stage I Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C6671',
#                'parents': ['C88888', 'C2926'],
#                'preferred_name': 'Stage I Non-Small Cell Lung Cancer',
#                'synonyms': ['Stage I Non-Small Cell Lung Cancer',
#                             'Stage I NSCLC',
#                             'Stage I Non-Oat Cell Carcinoma of Lung',
#                             'Stage I Non-Oat Cell Carcinoma of the Lung',
#                             'Stage I Non-Oat Cell Lung Carcinoma',
#                             'Stage I Non-Small Cell Carcinoma of Lung',
#                             'Stage I Non-Small Cell Carcinoma of the Lung',
#                             'Stage I Non-Small Cell Lung Cancer AJCC v7',
#                             'Stage I Non-Small Cell Lung Carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C2991',
#                'parents': ['C7057'],
#                'preferred_name': 'Disease or Disorder',
#                'synonyms': ['Disease or Disorder',
#                             'Disease',
#                             'Diseases',
#                             'Diseases and Disorders',
#                             'Disorder',
#                             'Disorders',
#                             'condition',
#                             'disorder']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C7057',
#                'parents': ['root_node'],
#                'preferred_name': 'Disease, Disorder or Finding',
#                'synonyms': ['Disease, Disorder or Finding']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3262',
#                'parents': ['C2991'],
#                'preferred_name': 'Neoplasm',
#                'synonyms': ['Neoplasm',
#                             'Neoplasia',
#                             'Neoplastic Disease',
#                             'Neoplastic Growth',
#                             'neoplasia',
#                             'neoplasm',
#                             'tumor']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C27551',
#                'parents': ['C2991'],
#                'preferred_name': 'Disorder by Site',
#                'synonyms': ['Disorder by Site', 'Disease by Site']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3263',
#                'parents': ['C3262'],
#                'preferred_name': 'Neoplasm by Site',
#                'synonyms': ['Neoplasm by Site']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C4741',
#                'parents': ['C3262'],
#                'preferred_name': 'Neoplasm by Morphology',
#                'synonyms': ['Neoplasm by Morphology']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C2916',
#                'parents': ['C3709'],
#                'preferred_name': 'Carcinoma',
#                'synonyms': ['Carcinoma',
#                             'CARCINOMA, MALIGNANT',
#                             'Carcinoma, NOS',
#                             'Epithelial Carcinoma',
#                             'Epithelioma Malignant',
#                             'Malignant Epithelial Neoplasm',
#                             'Malignant Epithelial Tumor',
#                             'Malignant Epithelioma',
#                             'carcinoma',
#                             'epithelial carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3709',
#                'parents': ['C4741'],
#                'preferred_name': 'Epithelial Neoplasm',
#                'synonyms': ['Epithelial Neoplasm',
#                             'Epithelial Neoplasms, NOS',
#                             'Epithelioma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C26871',
#                'parents': ['C27669'],
#                'preferred_name': 'Respiratory System Disorder',
#                'synonyms': ['Respiratory System Disorder',
#                             'Disorder of Respiratory System',
#                             'Respiratory Disorder']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C27669',
#                'parents': ['C27551'],
#                'preferred_name': 'Respiratory and Thoracic Disorder',
#                'synonyms': ['Respiratory and Thoracic Disorder',
#                             'Respiratory and Thoracic Disease',
#                             'Respiratory, Thoracic, and Mediastinal Disease',
#                             'Respiratory, Thoracic, and Mediastinal Disorder']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C35742',
#                'parents': ['C27669'],
#                'preferred_name': 'Thoracic Disorder',
#                'synonyms': ['Thoracic Disorder', 'Thoracic Disease']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3406',
#                'parents': ['C35742', 'C3263'],
#                'preferred_name': 'Thoracic Neoplasm',
#                'synonyms': ['Thoracic Neoplasm',
#                             'Neoplasm of Thorax',
#                             'Neoplasm of the Thorax',
#                             'Thoracic Tumor',
#                             'Tumor of Thorax',
#                             'Tumor of the Thorax']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C65151',
#                'parents': ['C2916'],
#                'preferred_name': 'Non-Small Cell Carcinoma',
#                'synonyms': ['Non-Small Cell Carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C7377',
#                'parents': ['C4571', 'C3576', 'C3200'],
#                'preferred_name': 'Malignant Lung Neoplasm',
#                'synonyms': ['Malignant Lung Neoplasm',
#                             'Malignant Lung Tumor',
#                             'Malignant Neoplasm of Lung',
#                             'Malignant Neoplasm of the Lung',
#                             'Malignant Tumor of Lung',
#                             'Malignant Tumor of the Lung']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3200',
#                'parents': ['C3406', 'C3355', 'C3198'],
#                'preferred_name': 'Lung Neoplasm',
#                'synonyms': ['Lung Neoplasm',
#                             'Lung Neoplasms',
#                             'Lung Tumor',
#                             'Neoplasm of Lung',
#                             'Neoplasm of the Lung',
#                             'Tumor of Lung',
#                             'Tumor of the Lung']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3355',
#                'parents': ['C3263', 'C26871'],
#                'preferred_name': 'Respiratory Tract Neoplasm',
#                'synonyms': ['Respiratory Tract Neoplasm',
#                             'Neoplasm of Respiratory Tract',
#                             'Neoplasm of the Respiratory Tract',
#                             'Respiratory Tract Tumor',
#                             'Tumor of Respiratory Tract',
#                             'Tumor of the Respiratory Tract']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C4571',
#                'parents': ['C3355'],
#                'preferred_name': 'Malignant Respiratory Tract Neoplasm',
#                'synonyms': ['Malignant Respiratory Tract Neoplasm',
#                             'Malignant Neoplasm of Respiratory Tract',
#                             'Malignant Neoplasm of the Respiratory Tract',
#                             'Malignant Respiratory Tract Tumor',
#                             'Malignant Tumor of Respiratory Tract',
#                             'Malignant Tumor of the Respiratory Tract']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C91232',
#                'parents': ['C4878'],
#                'preferred_name': 'Lung Carcinoma by AJCC v7 Stage',
#                'synonyms': ['Lung Carcinoma by AJCC v7 Stage']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C88888',
#                'parents': ['C91232'],
#                'preferred_name': 'Stage I Lung Cancer',
#                'synonyms': ['Stage I Lung Cancer',
#                             'Stage I Lung Cancer AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5643',
#                'parents': ['C88888'],
#                'preferred_name': 'Stage IB Lung Carcinoma',
#                'synonyms': ['Stage IB Lung Carcinoma',
#                             'Stage IB Carcinoma of Lung',
#                             'Stage IB Carcinoma of the Lung',
#                             'Stage IB Lung Carcinoma AJCC v7']},
#               {'disease_code': 'CDR0000041327',
#                'display_name': 'Stage II Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C7777',
#                'parents': ['C88889', 'C2926'],
#                'preferred_name': 'Stage II Non-Small Cell Lung Cancer',
#                'synonyms': ['Stage II Non-Small Cell Lung Cancer',
#                             'Non -Small Cell Lung Cancer Stage II',
#                             'Non Small Cell Lung Cancer Stage II',
#                             'Stage II Non-Oat Cell Carcinoma of Lung',
#                             'Stage II Non-Oat Cell Carcinoma of the Lung',
#                             'Stage II Non-Oat Cell Lung Carcinoma',
#                             'Stage II Non-Small Cell Carcinoma of Lung',
#                             'Stage II Non-Small Cell Carcinoma of the Lung',
#                             'Stage II Non-Small Cell Lung Cancer AJCC v7',
#                             'Stage II Non-Small Cell Lung Carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C88889',
#                'parents': ['C91232'],
#                'preferred_name': 'Stage II Lung Cancer',
#                'synonyms': ['Stage II Lung Cancer',
#                             'Stage II Lung Cancer AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5644',
#                'parents': ['C88889'],
#                'preferred_name': 'Stage IIA Lung Carcinoma',
#                'synonyms': ['Stage IIA Lung Carcinoma',
#                             'Stage IIA Carcinoma of Lung',
#                             'Stage IIA Carcinoma of the Lung',
#                             'Stage IIA Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5645',
#                'parents': ['C88889'],
#                'preferred_name': 'Stage IIB Lung Carcinoma',
#                'synonyms': ['Stage IIB Lung Carcinoma',
#                             'Stage IIB Carcinoma of Lung',
#                             'Stage IIB Carcinoma of the Lung',
#                             'Stage IIB Lung Carcinoma AJCC v7']},
#               {'disease_code': 'CDR0000041428',
#                'display_name': 'Stage III Non-Small Cell Lung Cancer',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C7778',
#                'parents': ['C88890', 'C2926'],
#                'preferred_name': 'Stage III Non-Small Cell Lung Cancer',
#                'synonyms': ['Stage III Non-Small Cell Lung Cancer',
#                             'Stage III NSCLC',
#                             'Stage III Non-Oat Cell Carcinoma of Lung',
#                             'Stage III Non-Oat Cell Carcinoma of the Lung',
#                             'Stage III Non-Oat Cell Lung Carcinoma',
#                             'Stage III Non-Small Cell Carcinoma of Lung',
#                             'Stage III Non-Small Cell Carcinoma of the Lung',
#                             'Stage III Non-Small Cell Lung Cancer AJCC v7',
#                             'Stage III Non-Small Cell Lung Carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C88890',
#                'parents': ['C91232'],
#                'preferred_name': 'Stage III Lung Cancer',
#                'synonyms': ['Stage III Lung Cancer',
#                             'Stage III Lung Cancer AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C5646',
#                'parents': ['C88890'],
#                'preferred_name': 'Stage IIIA Lung Carcinoma',
#                'synonyms': ['Stage IIIA Lung Carcinoma',
#                             'Stage IIIA Carcinoma of Lung',
#                             'Stage IIIA Carcinoma of the Lung',
#                             'Stage IIIA Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3780',
#                'parents': ['C2916'],
#                'preferred_name': 'Large Cell Carcinoma',
#                'synonyms': ['Large Cell Carcinoma',
#                             'Carcinoma, Large Cell',
#                             'large cell carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C2852',
#                'parents': ['C7132', 'C2916'],
#                'preferred_name': 'Adenocarcinoma',
#                'synonyms': ['Adenocarcinoma',
#                             'ADENOCARCINOMA, MALIGNANT',
#                             'Adenocarcinoma, NOS',
#                             'adenocarcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C7132',
#                'parents': ['C3709'],
#                'preferred_name': 'Glandular Cell Neoplasm',
#                'synonyms': ['Glandular Cell Neoplasm',
#                             'Glandular Cell Epithelial Neoplasm',
#                             'Glandular Cell Epithelium Neoplasm']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C27745',
#                'parents': ['C65151', 'C2852'],
#                'preferred_name': 'Non-Small Cell Adenocarcinoma',
#                'synonyms': ['Non-Small Cell Adenocarcinoma',
#                             'Nonsmall Cell Adenocarcinoma']},
#               {'disease_code': 'CDR0000040108',
#                'display_name': 'Squamous Cell Lung Cancer',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3493',
#                'parents': ['C4878', 'C2929'],
#                'preferred_name': 'Squamous Cell Lung Carcinoma',
#                'synonyms': ['Squamous Cell Lung Carcinoma',
#                             'Epidermoid Cell Carcinoma of Lung',
#                             'Epidermoid Cell Carcinoma of the Lung',
#                             'Epidermoid Cell Lung Carcinoma',
#                             'Squamous Cell Carcinoma of Lung',
#                             'Squamous Cell Carcinoma of the Lung',
#                             'Squamous cell lung carcinoma']},
#               {'disease_code': None,
#                'display_name': 'Squamous Cell Carcinoma',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C2929',
#                'parents': ['C3792', 'C2916'],
#                'preferred_name': 'Squamous Cell Carcinoma',
#                'synonyms': ['Squamous Cell Carcinoma',
#                             'CARCINOMA, SQUAMOUS CELL, MALIGNANT',
#                             'Epidermoid Carcinoma',
#                             'Epidermoid Cell Cancer',
#                             'Malignant Epidermoid Cell Neoplasm',
#                             'Malignant Epidermoid Cell Tumor',
#                             'Malignant Squamous Cell Neoplasm',
#                             'Malignant Squamous Cell Tumor',
#                             'Squamous Carcinoma',
#                             'Squamous Cell Cancer',
#                             'Squamous Cell Epithelioma',
#                             'epidermoid carcinoma',
#                             'squamous cell carcinoma']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C3792',
#                'parents': ['C3709'],
#                'preferred_name': 'Squamous Cell Neoplasm',
#                'synonyms': ['Squamous Cell Neoplasm',
#                             'Epidermoid Cell Neoplasm',
#                             'Epidermoid Cell Tumor',
#                             'Squamous Cell Tumor']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C8764',
#                'parents': ['C88888', 'C3493'],
#                'preferred_name': 'Stage I Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage I Squamous Cell Lung Carcinoma',
#                             'Stage I Epidermoid Cell Carcinoma of Lung',
#                             'Stage I Epidermoid Cell Carcinoma of the Lung',
#                             'Stage I Epidermoid Cell Lung Carcinoma',
#                             'Stage I Squamous Cell Carcinoma of Lung',
#                             'Stage I Squamous Cell Carcinoma of the Lung',
#                             'Stage I Squamous Cell Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C8765',
#                'parents': ['C88889', 'C3493'],
#                'preferred_name': 'Stage II Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage II Squamous Cell Lung Carcinoma',
#                             'Lung Squamous Cell Carcinoma Stage II',
#                             'Stage II Epidermoid Cell Carcinoma of Lung',
#                             'Stage II Epidermoid Cell Carcinoma of the Lung',
#                             'Stage II Epidermoid Cell Lung Carcinoma',
#                             'Stage II Squamous Cell Carcinoma of Lung',
#                             'Stage II Squamous Cell Carcinoma of the Lung',
#                             'Stage II Squamous Cell Lung Carcinoma AJCC v7']},
#               {'disease_code': None,
#                'display_name': '',
#                'inclusion_indicator': 'TREE',
#                'lead_disease_indicator': None,
#                'nci_thesaurus_concept_id': 'C8766',
#                'parents': ['C88890', 'C3493'],
#                'preferred_name': 'Stage III Squamous Cell Lung Carcinoma',
#                'synonyms': ['Stage III Squamous Cell Lung Carcinoma',
#                             'Lung Squamous Cell Carcinoma Stage III',
#                             'Stage III Epidermoid Cell Carcinoma of Lung',
#                             'Stage III Epidermoid Cell Carcinoma of the Lung',
#                             'Stage III Epidermoid Cell Lung Carcinoma',
#                             'Stage III Squamous Cell Carcinoma of Lung',
#                             'Stage III Squamous Cell Carcinoma of the Lung',
#                             'Stage III Squamous Cell Lung Carcinoma AJCC v7']}],
#  'eligibility': {'structured': {'gender': 'BOTH',
#                                 'max_age': '999 Years',
#                                 'max_age_in_years': 999,
#                                 'max_age_number': 999,
#                                 'max_age_unit': 'Years',
#                                 'min_age': '18 Years',
#                                 'min_age_in_years': 18,
#                                 'min_age_number': 18,
#                                 'min_age_unit': 'Years'},
#                  'unstructured': [{'description': 'PATIENT PRE-REGISTRATION '
#                                                   'ELIGIBILITY CRITERIA:',
#                                    'display_order': 1,
#                                    'inclusion_indicator': True},
#                                   {'description': 'For pre-surgical '
#                                                   'patients\r\n'
#                                                   '* Suspected diagnosis of '
#                                                   'resectable non-small cell '
#                                                   'lung cancer; patients with '
#                                                   'squamous cell carcinoma are '
#                                                   'eligible only if the '
#                                                   'registering site has EA5142 '
#                                                   'institutional review board '
#                                                   '(IRB) approved\r\n'
#                                                   '* Suspected clinical stage '
#                                                   'of IIIA, II or large IB '
#                                                   '(defined as size >= 4cm)',
#                                    'display_order': 2,
#                                    'inclusion_indicator': True},
#                                   {'description': 'For post-surgical '
#                                                   'patients\r\n'
#                                                   '* Completely resected '
#                                                   'non-small cell lung cancer; '
#                                                   'patients with squamous cell '
#                                                   'carcinoma are eligible only '
#                                                   'if the registering site has '
#                                                   'EA5142 IRB approved\r\n'
#                                                   '* Pathologic stage IIIA, II '
#                                                   'or IB (defined as size >= 4 '
#                                                   'cm)',
#                                    'display_order': 3,
#                                    'inclusion_indicator': True},
#                                   {'description': 'Eastern Cooperative '
#                                                   'Oncology Group (ECOG) '
#                                                   'performance status 0-1',
#                                    'display_order': 4,
#                                    'inclusion_indicator': True},
#                                   {'description': 'No patients who have '
#                                                   'received neoadjuvant '
#                                                   'therapy (chemo- or '
#                                                   'radio-therapy) for this '
#                                                   'lung cancer',
#                                    'display_order': 5,
#                                    'inclusion_indicator': True},
#                                   {'description': 'No prior or concurrent '
#                                                   'malignancies within 5 '
#                                                   'years, except non-melanoma '
#                                                   'skin carcinoma or in situ '
#                                                   'carcinomas; a secondary '
#                                                   'primary lung cancer is '
#                                                   'considered a concurrent '
#                                                   'malignancy and would make a '
#                                                   'patient ineligible for '
#                                                   'A151216',
#                                    'display_order': 6,
#                                    'inclusion_indicator': True},
#                                   {'description': 'No prior treatment with '
#                                                   'agents targeting EGFR '
#                                                   'mutation, ALK '
#                                                   'rearrangement, and '
#                                                   'PD-1/PD-L1/CTLA-4',
#                                    'display_order': 7,
#                                    'inclusion_indicator': True},
#                                   {'description': 'No patients known to be '
#                                                   'pregnant or lactating',
#                                    'display_order': 8,
#                                    'inclusion_indicator': True},
#                                   {'description': 'Patients who have had local '
#                                                   'genotyping are eligible, '
#                                                   'regardless of the local '
#                                                   'result',
#                                    'display_order': 9,
#                                    'inclusion_indicator': True},
#                                   {'description': 'No patients with recurrence '
#                                                   'of lung cancer after prior '
#                                                   'resection',
#                                    'display_order': 10,
#                                    'inclusion_indicator': True},
#                                   {'description': 'Note: Post-surgical '
#                                                   'patients should proceed to '
#                                                   'registration immediately '
#                                                   'following preregistration',
#                                    'display_order': 11,
#                                    'inclusion_indicator': True},
#                                   {'description': 'PATIENT REGISTRATION '
#                                                   'ELIGIBILITY CRITERIA:',
#                                    'display_order': 12,
#                                    'inclusion_indicator': True},
#                                   {'description': 'Completely resected NSCLC; '
#                                                   'patients with squamous cell '
#                                                   'carcinoma are eligible only '
#                                                   'if the registering site has '
#                                                   'EA5142 IRB approved',
#                                    'display_order': 13,
#                                    'inclusion_indicator': True},
#                                   {'description': 'Pathologic stage IIIA, II, '
#                                                   'or large IB (defined as '
#                                                   'size >= 4 cm)',
#                                    'display_order': 14,
# ...
#             'org_family': 'Harold C. Simmons Comprehensive Cancer Center',
#             'org_fax': None,
#             'org_name': 'UT Southwestern / Simmons Cancer Center-Dallas',
#             'org_phone': '214-648-7097',
#             'org_postal_code': '75390',
#             'org_state_or_province': 'TX',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-05-21',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-05-21'},
#            {'contact_email': 'cancer.research.nurse@dartmouth.edu',
#             'contact_name': 'Konstantin Hristov Dragnev',
#             'contact_phone': '800-639-6918',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '87 McGregor Street',
#             'org_address_line_2': 'Notre Dame Pavilion Fourth Floor',
#             'org_city': 'Manchester',
#             'org_coordinates': {'lat': 43.0067, 'lon': -71.4926},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'Norris Cotton Cancer Center',
#             'org_fax': None,
#             'org_name': 'Norris Cotton Cancer Center-Manchester',
#             'org_phone': '603-629-1828',
#             'org_postal_code': '03102',
#             'org_state_or_province': 'NH',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-07-27',
#             'org_to_family_relationship': 'AFFILIATION',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-01-06'},
#            {'contact_email': None,
#             'contact_name': 'Susanne Markesbery Arnold',
#             'contact_phone': '859-257-3379',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '800 Rose Street',
#             'org_address_line_2': None,
#             'org_city': 'Lexington',
#             'org_coordinates': {'lat': 38.0316, 'lon': -84.5089},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'University of Kentucky - Markey Cancer Center',
#             'org_fax': None,
#             'org_name': 'University of Kentucky / Markey Cancer Center',
#             'org_phone': '859-257-3379',
#             'org_postal_code': '40536',
#             'org_state_or_province': 'KY',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-03-19',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-01-23'},
#            {'contact_email': None,
#             'contact_name': 'Matthew James Schuchert',
#             'contact_phone': '412-647-2811',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '100 Fairfield Drive',
#             'org_address_line_2': None,
#             'org_city': 'Seneca',
#             'org_coordinates': {'lat': 41.3544, 'lon': -79.6606},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'University of Pittsburgh Cancer Institute',
#             'org_fax': None,
#             'org_name': 'UPMC Cancer Center at UPMC Northwest',
#             'org_phone': '814-676-7900',
#             'org_postal_code': '16346',
#             'org_state_or_province': 'PA',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2014-01-27',
#             'org_to_family_relationship': 'AFFILIATION',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-01-26'},
#            {'contact_email': None,
#             'contact_name': 'Dhimant R. Patel',
#             'contact_phone': '800-252-2990',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '855 North Westhaven Drive',
#             'org_address_line_2': None,
#             'org_city': 'Oshkosh',
#             'org_coordinates': {'lat': 43.9694, 'lon': -88.6465},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'University of Wisconsin Carbone Cancer Center',
#             'org_fax': None,
#             'org_name': 'Vince Lombardi Cancer Clinic - Oshkosh',
#             'org_phone': '800-252-2990',
#             'org_postal_code': '54904',
#             'org_state_or_province': 'WI',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-07-30',
#             'org_to_family_relationship': 'AFFILIATION',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-01-27'},
#            {'contact_email': None,
#             'contact_name': 'Barbara Jennifer Gitlitz',
#             'contact_phone': '323-865-0451',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '1200 North State Street',
#             'org_address_line_2': None,
#             'org_city': 'Los Angeles',
#             'org_coordinates': {'lat': 34.0504, 'lon': -118.211},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'USC Norris Comprehensive Cancer Center',
#             'org_fax': None,
#             'org_name': 'Los Angeles County-USC Medical Center',
#             'org_phone': '323-865-0451',
#             'org_postal_code': '90033',
#             'org_state_or_province': 'CA',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2012-12-06',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-03-27'},
#            {'contact_email': None,
#             'contact_name': 'Justinian Rugakingira Ngaiza',
#             'contact_phone': '866-922-6237',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '100 East Carroll Street',
#             'org_address_line_2': None,
#             'org_city': 'Salisbury',
#             'org_coordinates': {'lat': 38.3511, 'lon': -75.5976},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'Sidney Kimmel Comprehensive Cancer Center',
#             'org_fax': None,
#             'org_name': 'Peninsula Regional Medical Center',
#             'org_phone': '410-543-7000',
#             'org_postal_code': '21801',
#             'org_state_or_province': 'MD',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2008-12-30',
#             'org_to_family_relationship': 'AFFILIATION',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2016-10-21'},
#            {'contact_email': None,
#             'contact_name': 'Joseph Aisner',
#             'contact_phone': '732-235-8675',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': 'One Robert Wood Johnson Place',
#             'org_address_line_2': None,
#             'org_city': 'New Brunswick',
#             'org_coordinates': {'lat': 40.5102, 'lon': -74.447},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'Rutgers Cancer Institute of New Jersey',
#             'org_fax': None,
#             'org_name': 'Rutgers Cancer Institute of New Jersey-Robert Wood '
#                         'Johnson University Hospital',
#             'org_phone': '732-235-8675',
#             'org_postal_code': '08903',
#             'org_state_or_province': 'NJ',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-11-30',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-07-08'},
#            {'contact_email': 't.carducci@kennedyhealth.org',
#             'contact_name': 'Trina A. Poretta',
#             'contact_phone': '856-218-5790',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '900 Medical Center Drive',
#             'org_address_line_2': 'Suite 100',
#             'org_city': 'Sewell',
#             'org_coordinates': {'lat': 39.7561, 'lon': -75.1094},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'Abramson Cancer Center',
#             'org_fax': None,
#             'org_name': 'Kennedy Health Systems-Cancer Center',
#             'org_phone': None,
#             'org_postal_code': '08080',
#             'org_state_or_province': 'NJ',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2012-12-03',
#             'org_to_family_relationship': 'AFFILIATION',
#             'org_tty': None,
#             'recruitment_status': 'TEMPORARILY_CLOSED_TO_ACCRUAL',
#             'recruitment_status_date': '2017-01-09'},
#            {'contact_email': 'jhcccro@jhmi.edu',
#             'contact_name': 'Patrick M. Forde',
#             'contact_phone': '410-955-8804',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '600 North Wolfe Street',
#             'org_address_line_2': None,
#             'org_city': 'Baltimore',
#             'org_coordinates': {'lat': 39.3021, 'lon': -76.5621},
#             'org_country': 'United States',
#             'org_email': 'jhcccro@jhmi.edu',
#             'org_family': 'Sidney Kimmel Comprehensive Cancer Center',
#             'org_fax': None,
#             'org_name': 'Johns Hopkins University / Sidney Kimmel Cancer '
#                         'Center',
#             'org_phone': '410-955-8804',
#             'org_postal_code': '21287',
#             'org_state_or_province': 'MD',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-05-05',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-05-05'},
#            {'contact_email': None,
#             'contact_name': 'Linda L. Garland',
#             'contact_phone': '520-626-9008',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '1501 North Campbell Avenue',
#             'org_address_line_2': None,
#             'org_city': 'Tucson',
#             'org_coordinates': {'lat': 32.2468, 'lon': -110.9447},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'Arizona Cancer Center',
#             'org_fax': None,
#             'org_name': 'The University of Arizona Medical Center-University '
#                         'Campus',
#             'org_phone': '520-626-9008',
#             'org_postal_code': '85724',
#             'org_state_or_province': 'AZ',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-05-05',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-10-13'},
#            {'contact_email': None,
#             'contact_name': 'Thomas Lee Bauer',
#             'contact_phone': '732-776-4240',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': 'One Riverview Plaza',
#             'org_address_line_2': None,
#             'org_city': 'Red Bank',
#             'org_coordinates': {'lat': 40.3609, 'lon': -74.079},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'Rutgers Cancer Institute of New Jersey',
#             'org_fax': None,
#             'org_name': 'Riverview Medical Center / Booker Cancer Center',
#             'org_phone': '732-530-2382',
#             'org_postal_code': '07701',
#             'org_state_or_province': 'NJ',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-07-27',
#             'org_to_family_relationship': 'AFFILIATION',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-06-05'},
#            {'contact_email': 'Jamesline@osumc.edu',
#             'contact_name': 'Gregory A. Otterson',
#             'contact_phone': '800-293-5066',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '410 West Tenth Avenue',
#             'org_address_line_2': None,
#             'org_city': 'Columbus',
#             'org_coordinates': {'lat': 40.0051, 'lon': -83.0218},
#             'org_country': 'United States',
#             'org_email': 'Jamesline@osumc.edu',
#             'org_family': 'Comprehensive Cancer Center - James Cancer Hospital '
#                           '& Solove Research Institute',
#             'org_fax': None,
#             'org_name': 'Ohio State University Comprehensive Cancer Center',
#             'org_phone': '866-627-7616',
#             'org_postal_code': '43210',
#             'org_state_or_province': 'OH',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2014-12-02',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-05-12'},
#            {'contact_email': None,
#             'contact_name': 'Ticiana Batista Leal',
#             'contact_phone': '877-405-6866',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '600 Highland Avenue',
#             'org_address_line_2': None,
#             'org_city': 'Madison',
#             'org_coordinates': {'lat': 43.0769, 'lon': -89.4329},
#             'org_country': 'United States',
#             'org_email': None,
#             'org_family': 'University of Wisconsin Carbone Cancer Center',
#             'org_fax': None,
#             'org_name': 'University of Wisconsin Hospital and Clinics',
#             'org_phone': '608-262-5223',
#             'org_postal_code': '53792',
#             'org_state_or_province': 'WI',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2008-12-31',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-12-02'},
#            {'contact_email': 'JME3D@hscmail.mcc.virginia.edu',
#             'contact_name': 'Richard Delmar Hall',
#             'contact_phone': '434-243-6322',
#             'generic_contact': None,
#             'local_site_identifier': '',
#             'org_address_line_1': '1300 Jefferson Park Avenue',
#             'org_address_line_2': None,
#             'org_city': 'Charlottesville',
#             'org_coordinates': {'lat': 38.0346, 'lon': -78.5162},
#             'org_country': 'United States',
#             'org_email': 'JME3D@hscmail.mcc.virginia.edu',
#             'org_family': 'UVA Cancer Center',
#             'org_fax': None,
#             'org_name': 'University of Virginia Cancer Center',
#             'org_phone': '434-243-6143',
#             'org_postal_code': '22908',
#             'org_state_or_province': 'VA',
#             'org_status': 'ACTIVE',
#             'org_status_date': '2015-06-02',
#             'org_to_family_relationship': 'ORGANIZATIONAL',
#             'org_tty': None,
#             'recruitment_status': 'ACTIVE',
#             'recruitment_status_date': '2015-06-02'}],
#  'start_date': '2014-08-18',
#  'start_date_type_code': 'ACTUAL',
#  'study_model_code': 'CASE_ONLY',
#  'study_model_other_text': 'Need to be reviewed by scientific abstractor',
#  'study_population_description': 'Patients with stage IB-IIIA non-small cell '
#                                  'lung cancer',
#  'study_protocol_type': 'Non-interventional',
#  'study_subtype_code': 'OBSERVATIONAL'}

# %% [markdown]
# ### 2. Query the API using arguments
#
# Read the documentation for the API on the website, and retrieve the data to get all trial IDs for all trials in NY where the eligibility criteria was restricted to women and whose primary purpose was basic science.

# %%
# Use the API documentation to understand the nature of the arguements. Chain them together, and get the response
api_args = "clinical-trials?eligibility.structured.gender=female&include=nct_id&sites.org_state_or_province=NY"

# store response
json_text = get_response_json(api_args=api_args)

# eyeball the response
pprint(json_text)
# Out:
# {'total': 212,
#  'trials': [{'nct_id': 'NCT01272037'},
#             {'nct_id': 'NCT02750826'},
#             {'nct_id': 'NCT01953588'},
#             {'nct_id': 'NCT00565851'},
#             {'nct_id': 'NCT02311933'},
#             {'nct_id': 'NCT01872975'},
#             {'nct_id': 'NCT01101451'},
#             {'nct_id': 'NCT02101788'},
#             {'nct_id': 'NCT02065687'},
#             {'nct_id': 'NCT02446600'}]}

# %% [markdown]
# ### 3. Structure the JSON data
#
# Pandas is a very useful python library that allows you to view data in tabular form. It is very good (and fast!) for viewing CSV file and even connecting to databases. For this exercise, we shall use it to structure the JSON data in a more readable format.
#
# Hint: use the function:
#
# ```pd.io.json.json_normalize()```
#
# (This will help it to read data from nested JSON files i.e. where dictionaries and lists are embedded within others).

# %%
# From the json text, retrive the list of trials by using the key
trial_array = json_text['trials']

# Using pandas functions, convert the JSON into a Data Frame.
trial_df = pd.io.json.json_normalize(trial_array)

# Use the head function to view what is in the data fram. Note the header name "nct_id".
print(trial_df.head())

# Each column can be accessed using the name
trail_list = list(trial_df["nct_id"])
# Out:
#         nct_id
# 0  NCT01272037
# 1  NCT02750826
# 2  NCT01953588
# 3  NCT00565851
# 4  NCT02311933

# %% [markdown]
# ### 4. Scrape Data using a spider
#
# In this part, we shall use Scrapy (another python library) to create a "Spider" to crawl the websites to gather data.
# Scrapy documentation has a nice tutorial to get started at https://doc.scrapy.org/en/latest/intro/tutorial.html. We shall be modifying the code here for our purpose.
#
# To get started you can type "!scrapy startproject tutorial" in a new cell. This allows you to run command line arguements from within Jupyter, which can often be handy. The command will create a directory structure that can be used by your Scrapy commands.
#
# The code from the tutorial is below:
#
# Your objective are:
#
# 1. Create a meaningful query (use the query from Part 2, if nothing comes to mind) to get data from the API
# 2. Then get ALL the data from the trials retrieved by your query, and save them in individual files.
#
# Be sure to change the name of the variable as well the class to something meaninful, and use "scrapy _spiderName_" from the command line to run the spider.
#
# HINT: Replace the url list in the code snippet below, and construct that list within the start_requests function. Remember to save the code (including the imports) in a file appropriately named (for e.g.

# %%
# !scrapy startproject tutorial
# Out:
# New Scrapy project 'tutorial', using template directory '/home/sayan/anaconda3/lib/python3.5/site-packages/scrapy/templates/project', created in:
#     /home/sayan/Masters/Career/UCSF/health-analytics-ucsf/week_1/tutorial
#
# You can start your first spider with:
#     cd tutorial
#     scrapy genspider example example.com

# %%
class QuotesSpider(scrapy.Spider):
    name = "quotes"

    def start_requests(self):
        urls = [
            'http://quotes.toscrape.com/page/1/',
            'http://quotes.toscrape.com/page/2/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        page = response.url.split("/")[-2]
        filename = 'quotes-%s.html' % page
        with open(filename, 'wb') as f:
            f.write(response.body)
        self.log('Saved file %s' % filename)

# %% [markdown]
#  - METAL https://github.com/Kitware/MetaIO
#  - DICOM – Waveform An extension of Dicom for storing waveform data
#  - European Data Format (.edf, .rec)
#  - CSV (.csv),XML,TXT
#  - ecgML – A markup language for electrocardiogram data acquisition and analysis.
#  - EDF/EDF+ – European Data Format.
#  - FEF – File Exchange Format for Vital signs, CEN TS 14271.
#  - GDF v1.x – The General Data Format for biomedical signals – Version 1.x.
#  - GDF v2.x – The General Data Format for biomedical signals – Version 2.x.
#  - HL7aECG – Health Level 7 v3 annotated ECG.
#  - MFER – Medical waveform Format Encoding Rules
#  - OpenXDF – Open Exchange Data Format
#  - TDMS (.tdms)
#  - LVM (.lvm)
#  - SCP-ECG – Standard Communication Protocol for Computer assisted electrocardiography EN1064:2007,
#  - SIGIF – A digital SIGnal Interchange Format with application in neurophysiology.
#  - WFDB – Format of Physiobank
